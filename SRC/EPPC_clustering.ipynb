# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### TÍTULO

# %% [markdown]
# Titulo = "El quién, el qué y el cuánto del consumo cultural en Cataluña"

# %% [markdown]
# ### TEMA

# %% [markdown]
# Tema = "Predicción de tipos y volúmenes de consumo cultural en función de los perfiles de usaurio en Cataluña, según las Encuestas de Participación Cultural de la Generalitat de los años 2018 a 2023"

# %% [markdown]
# ### OBJETIVO

# %% [markdown]
# Define aquí lo que serán los objetivos de tu proyecto.

# %% [markdown]
# Objetivo 1 = Predecir qué y cuánta cultura consumirá un ciudadano X dado su perfil (X ciudadano, que es /tiene/ hace/ viene de/ piensa X, etc, visitará x veces un museo / cine/etc.)<br>
# Objetivo 2 = Clasificar los hábitos de consumo cultural según variables tradicionales / demográficas (qué consumen los jóvenes, las mujeres de más de 60, los adultos de zonas rurales).<br>
# Objetivo 3 = Encontrar perfiles de usuarios de cultura en función de los hábitos y gustos, no de la demografía a partir de patrones de consumo común y mediante clustering, y descubrir qué variables resultan más relevantes<br>

# %% [markdown]
# POSIBLEMENTE NO: (Demasiado trabajo extra y no tanta relevancia para este proyecto, aunque a mi me parezca interesante)
# Objetivo 4 = Hacer un clustering a partir de los datos de 1028 siguiendo el mismo criterio que con los datos de 2018, y analizar en qué medida hay o no cambios.<br>

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una vista del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %% [markdown]
# Enquesta de participació cultural de la Generalitat de Catalunya (2018, 2019, 2020, 2021, 2022, 2023)
#
# Lo más probable es que solo trabaje con los datos de 2023, y no con la evolución de las prácticas culturales a través de losaños.
#
# https://analisi.transparenciacatalunya.cat/ca/browse?q=enquesta%20participacio%20cultural

# %%
import numpy as np
import pandas as pd
import os
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense

# %%
epcc23 = pd.read_excel('./data/BBDD_EPCC_23.xlsx')

# %%
epcc23.head()
# Out:
#     ID    Elevació Mètode SEXE   EDAT AmbitTerritorial  \
# 0  100  674.941909   CAWI    H  14-19      METROPOLITÀ
# 1  201  674.941909   CAWI    H  14-19      METROPOLITÀ
# 2  202  674.941909   CATI    H  14-19      METROPOLITÀ
# 3  303  674.941909   CAWI    H  14-19      METROPOLITÀ
# 4  501  674.941909   CAWI    H  14-19      METROPOLITÀ
#
#                  GrandariaMunicipi  I1  I2EA  I2EB  ...  CS6  CS11  CS12  \
# 0  MÉS DE 50.000 - RESTA CATALUNYA   2     1    15  ...  NaN   2.0   NaN
# 1  MÉS DE 50.000 - RESTA CATALUNYA   2     1    16  ...  NaN   2.0   NaN
# 2  MÉS DE 50.000 - RESTA CATALUNYA   1     1    16  ...  NaN   2.0   NaN
# 3  MÉS DE 50.000 - RESTA CATALUNYA   1     1    16  ...  NaN   2.0   NaN
# 4  MÉS DE 50.000 - RESTA CATALUNYA   1     1    16  ...  NaN   2.0   NaN
#
#    CS13  CS15A  CS15  CS21  G1    G2  G2A
# 0     3      2   1.0   NaN   1   7.0  NaN
# 1     2      3   1.0   NaN   2  99.0  NaN
# 2     2      3   1.0   NaN   2  99.0  NaN
# 3     2      3   1.0   NaN   2   5.0  NaN
# 4     2      3   1.0   NaN   2   NaN  NaN
#
# [5 rows x 519 columns]

# %% [markdown]
# #### Diccionario de códigos

# %%
dicc_codis = pd.read_excel("./data/diccionari_codis_23.xlsx")

# %%
dicc_codis.head()
# Out:
#   Valors de les variables  Unnamed: 1  \
# 0                   Valor         NaN
# 1                      I1         0.0
# 2                     NaN         1.0
# 3                     NaN         2.0
# 4                    I2EA         1.0
#
#                                        Unnamed: 2
# 0                                        Etiqueta
# 1  Ningú de la llar parla cap d’aquestes llengües
# 2                                          Català
# 3                                        Castellà
# 4                                            Home

# %% [markdown]
# #### Diccionario de variables

# %%
dicc_variables = pd.read_excel("./data/diccionari_variables_23.xlsx")

# %%
dicc_variables.head()
# Out:
#   Informació de les variables Unnamed: 1     Unnamed: 2         Unnamed: 3  \
# 0                    Variable   Posición       Etiqueta  Nivel de medición
# 1                          ID          1  Identificador            Nominal
# 2                    Elevació          2       Elevació             Escala
# 3                      Mètode          3         Mètode            Nominal
# 4                       ORDRE          4          Ordre            Nominal
#
#   Unnamed: 4        Unnamed: 5  Unnamed: 6            Unnamed: 7  \
# 0        Rol  Ancho de columna  Alineación  Formato de impresión
# 1    Entrada                 5     Derecha                    F8
# 2    Entrada                 5     Derecha                 F11.6
# 3    Entrada                 5   Izquierda                    A4
# 4    Entrada                 5   Izquierda                    A2
#
#              Unnamed: 8
# 0  Formato de grabación
# 1                    F8
# 2                 F11.6
# 3                    A4
# 4                    A2

# %% [markdown]
# -------------------------------------

# %% [markdown]
# ### Limpieza de datos

# %%
epcc23co = epcc23.copy()

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
epcc23.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4124 entries, 0 to 4123
# Columns: 519 entries, ID to G2A
# dtypes: float64(447), int64(46), object(26)
# memory usage: 16.3+ MB

# %% [markdown]
# ##### Primero voy a trabajar las columnas que tienen strings para convertirlas en numéricas

# %% [markdown]
# ##### Empiezo con los binarios

# %%
print(epcc23['Mètode'].unique())
# Out:
# ['CAWI' 'CATI']

# %%
epcc23['Mètode'] = epcc23['Mètode'].map({'CAWI': 0, 'CATI': 1})

# %%
print(epcc23['SEXE'].unique())
# Out:
# ['H' 'D']

# %%
epcc23['SEXE'] = epcc23['SEXE'].map({'H': 0, 'D': 1})

# %% [markdown]
# ##### Ahora los ordinales

# %%
print(epcc23['EDAT'].unique())
# Out:
# ['14-19' '20-24' '35-54' '25-34' '>=55']

# %%
# Convertir la columna EDAT a una escala
age_mapping = {
    '14-19': 0,
    '20-24': 1,
    '25-34': 2,
    '35-54': 3,
    '>=55': 4
}
epcc23['EDAT'] = epcc23['EDAT'].map(age_mapping)

# %% [markdown]
# ##### Y ahora las demás que quedan para One hot encoding

# %%
print(epcc23['AmbitTerritorial'].unique())
# Out:
# ['METROPOLITÀ' 'PENEDÈS' 'COMARQUES CENTRALS' 'COMARQUES GIRONINES'
#  'CAMP DE TARRAGONA' 'ALT PIRINEU I ARAN' "TERRES DE L'EBRE" 'PONENT']

# %%
# Convertir la columna AmbitTerritorial a one-hot encoding
epcc23 = pd.get_dummies(epcc23, columns=['AmbitTerritorial'])

# %%
print(epcc23['GrandariaMunicipi'].unique())
# Out:
# ['MÉS DE 50.000 - RESTA CATALUNYA' 'BARCELONA CIUTAT' 'DE 10.001 A 50.000'
#  'DE 2.001 A 10.000' 'FINS A 2.000']

# %%
epcc23 = pd.get_dummies(epcc23, columns=['GrandariaMunicipi'])

# %%
# A ver cuántos NaN tengo:
nan_percentage = epcc23.isna().mean() * 100

# Crear un DataFrame con la información
nan_info = pd.DataFrame({
    'Column': nan_percentage.index,
    'NaN_Percentage': nan_percentage.values
})

# Mostrar el DataFrame ordenado por el porcentaje de NaNs
nan_info_sorted = nan_info.sort_values(by='NaN_Percentage', ascending=False)
print(nan_info_sorted)
# Out:
#                                                 Column  NaN_Percentage
# 195                                            VJO8#95           100.0
# 196                                            VJO8#99           100.0
# 176                                            VJO6#99           100.0
# 241                                               M7#9           100.0
# 477                                            LN7#2#4           100.0
# ..                                                 ...             ...
# 372                                                LL1             0.0
# 335                                                EX1             0.0
# 312                                                ES1             0.0
# 278                                                CN1             0.0
# 529  GrandariaMunicipi_MÉS DE 50.000 - RESTA CATALUNYA             0.0
#
# [530 rows x 2 columns]

# %%
nan_info_nonzero = nan_info_sorted[nan_info_sorted['NaN_Percentage'] > 0]
print(nan_info_nonzero)
# Out:
#         Column  NaN_Percentage
# 195    VJO8#95      100.000000
# 196    VJO8#99      100.000000
# 176    VJO6#99      100.000000
# 241       M7#9      100.000000
# 477    LN7#2#4      100.000000
# ..         ...             ...
# 69   CA6#value        0.193986
# 474    LN7#2#1        0.169738
# 30   PP3#value        0.169738
# 42    R3#value        0.169738
# 20    D3#value        0.048497
#
# [463 rows x 2 columns]

# %% [markdown]
# #### Antes de procesar los nulos, vamos a trabajar los grupos de columnas codificadas

# %%
# Agrupar las encoded columns listas explícitas (las que son el resultado de un one hot encoding que representan diferentes opciones de respuesta a una misma pregunta)

encoded_groups = [
    ["D2#1", "D2#2", "D2#4", "D2#99"],
    ["D3#1", "D3#2","D3#3", "D3#99"],
    ["PP0#1", "PP0#2", "PP0#3", "PP0#99"],
    ["PP3#1","PP3#2","PP3#3","PP3#99"],
    ["R2#1", "R2#2", "R2#3", "R2#4", "R2#5", "R2#99"],
    ["R3#1", "R3#2", "R3#3", "R3#99"],
    ["CA2A#1","CA2A#2", "CA2A#3", "CA2A#4", "CA2A#5", "CA2A#6", "CA2A#99"],
    ["T4#2", "T4#3", "T4#4", "T4#5", "T4#6", "T4#7", "T4#8", "T4#11", "T4#99"],
    ["CA6#1", "CA6#2", "CA6#3", "CA6#4", "CA6#5", "CA6#6", "CA6#99"],
    ["CA4#2", "CA4#1", "CA4#3", "CA4#4", "CA4#99"],
    ["CA5#1", "CA5#2", "CA5#3", "CA5#4", "CA5#5", "CA5#6", "CA5#99"],
    ["IT4#1","IT4#2", "IT4#3", "IT4#4", "IT4#5", "IT4#6", "IT4#99"],
    ["IT6#1", "IT6#2", "IT6#3", "IT6#4","IT6#5", "IT6#6", "IT6#7", "IT6#8", "IT6#9", "IT6#10", "IT6#99"],
    ["VJO1#1", "VJO1#2", "VJO1#3", "VJO1#4", "VJO1#5", "VJO1#6", "VJO1#7", "VJO1#8", "VJO1#9", "VJO1#10", "VJO1#11", "VJO1#99"],
    ["VJ2#1", "VJ2#2", "VJ2#3", "VJ2#4", "VJ2#5", "VJ2#6", "VJ2#7", "VJ2#8", "VJ2#9", "VJ2#10", "VJ2#99"],
    ["VJ3#1", "VJ3#2", "VJ3#3", "VJ3#4", "VJ3#5", "VJ3#6", "VJ3#7", "VJ3#8", "VJ3#99"],
    ["VJ6#1", "VJ6#2", "VJ6#3", "VJ6#4", "VJ6#5", "VJ6#6", "VJ6#7", "VJ6#99"],
    ["VJ7#1", "VJ7#2", "VJ7#3", "VJ7#4", "VJ7#5", "VJ7#6", "VJ7#7", "VJ7#8", "VJ7#9", "VJ7#10", "VJ7#11", "VJ7#99"],
    ["VJO6#1", "VJO6#2", "VJO6#3", "VJO6#4", "VJO6#5", "VJO6#6", "VJO6#7", "VJO6#95", "VJO6#99"],
    ["VJO7A#1", "VJO7A#2", "VJO7A#99"],
    ["VJO8#1", "VJO8#2", "VJO8#3", "VJO8#4", "VJO8#5", "VJO8#6", "VJO8#7", "VJO8#8", "VJO8#9", "VJO8#95", "VJO8#99"],
    ["M3#1", "M3#2", "M3#3", "M3#4", "M3#5", "M3#6", "M3#7", "M3#99"],
    ["M4#1", "M4#7", "M4#9", "M4#10", "M4#11", "M4#13", "M4#18", "M4#19", "M4#99"],
    ["M5#1", "M5#2", "M5#3", "M5#4", "M5#5", "M5#6", "M5#7", "M5#8", "M5#9", "M5#99"],
    ["M7#1", "M7#2", "M7#3", "M7#4", "M7#5", "M7#6", "M7#7", "M7#8", "M7#9", "M7#10", "M7#11", "M7#99"],
    ["CO3#1", "CO3#2", "CO3#3", "CO3#4", "CO3#5", "CO3#6", "CO3#7", "CO3#99"],
    ["CO7#1", "CO7#2", "CO7#3", "CO7#4", "CO7#5", "CO7#6", "CO7#7", "CO7#8", "CO7#9", "CO7#10", "CO7#99"],
    ["CO9#1", "CO9#7", "CO9#9", "CO9#10", "CO9#11", "CO9#13", "CO9#18", "CO9#19", "CO9#99"],
    ["CN2#1", "CN2#2", "CN2#3", "CN2#4", "CN2#5", "CN2#6", "CN2#99"],
    ["CN5#1", "CN5#2", "CN5#3", "CN5#4", "CN5#5", "CN5#6", "CN5#9", "CN5#10", "CN5#11", "CN5#12", "CN5#13", "CN5#99"],
    ["CN6#1", "CN6#2", "CN6#3", "CN6#4", "CN6#5", "CN6#6", "CN6#7", "CN6#8", "CN6#9", "CN6#88", "CN6#99"],
    ["ES3#1", "ES3#2", "ES3#3", "ES3#4", "ES3#5", "ES3#6", "ES3#7", "ES3#99"],
    ["ES6#1", "ES6#2", "ES6#3", "ES6#4", "ES6#5", "ES6#6", "ES6#7", "ES6#8", "ES6#9", "ES6#88", "ES6#99"],
    ["EX7#1", "EX7#2", "EX7#3", "EX7#4", "EX7#5", "EX7#6", "EX7#7", "EX7#8", "EX7#9", "EX7#88", "EX7#99"],
    ["EX9#1", "EX9#2", "EX9#3", "EX9#4", "EX9#5", "EX9#6", "EX9#99"],
    ["EX13#1", "EX13#2", "EX13#3", "EX13#4", "EX13#7", "EX13#10", "EX13#11", "EX13#12", "EX13#99"],
    ["LL5#2", "LL5#3", "LL5#4", "LL5#5", "LL5#6", "LL5#7", "LL5#8", "LL5#9", "LL5#10", "LL5#11", "LL5#99"],
    ["LL5A#1", "LL5A#2", "LL5A#3", "LL5A#4", "LL5A#5", "LL5A#6", "LL5A#7", "LL5A#8", "LL5A#9", "LL5A#10", "LL5A#99"],
    ["LL11#2", "LL11#3", "LL11#4", "LL11#7", "LL11#9", "LL11#11", "LL11#12", "LL11#13", "LL11#16", "LL11#99"],
    ["BI2#1", "BI2#2", "BI2#3", "BI2#4", "BI2#99"],
    ["BI3#1", "BI3#2", "BI3#3", "BI3#5", "BI3#6", "BI3#7", "BI3#8", "BI3#10", "BI3#99"],
    ["AS2#1", "AS2#2", "AS2#3", "AS2#4", "AS2#5", "AS2#6", "AS2#7", "AS2#8", "AS2#9", "AS2#10", "AS2#11", "AS2#16", "AS2#17", "AS2#99"],
    ["LN2#1", "LN2#2", "LN2#3", "LN2#4", "LN2#5", "LN2#6", "LN2#99"],
    ["LN7#1#1", "LN7#1#2", "LN7#1#3", "LN7#1#4", "LN7#1#99"],
    ["LN7#2#1", "LN7#2#2", "LN7#2#3", "LN7#2#4", "LN7#2#99"],
    ["LN7#3#1", "LN7#3#2", "LN7#3#3", "LN7#3#4", "LN7#3#99"],
    ["LN7#4#0", "LN7#4#1", "LN7#4#2", "LN7#4#3", "LN7#4#9"],
]

# %%
modified_cells_count = 0

# %%
# Me aseguro de que, dentro de cada grupo de preguntas, si no hay ninguna opción marcada, que se marque la de NS/NC, 
# que es la correspondiente a la columna acabada en #99 dentro de dicho grupo

for group in encoded_groups:
    # Verifica que las columnas existan en el DataFrame
    valid_columns = [col for col in group if col in epcc23.columns]
    if valid_columns:
        non_ns_nc_cols = [col for col in valid_columns if not col.endswith('#99')]
        ns_nc_col = [col for col in valid_columns if col.endswith('#99')]
        
        if ns_nc_col:
            ns_nc_col = ns_nc_col[0]
            
            # Si ninguna columna tiene valor, poner 1 en la columna de NS/NC
            ns_nc_updates = epcc23[non_ns_nc_cols].sum(axis=1) == 0
            epcc23[ns_nc_col] = np.where(ns_nc_updates, 1, epcc23[ns_nc_col])
            modified_cells_count += ns_nc_updates.sum()
            
            # Rellenar con 0 las columnas que no tengan ningún valor dentro del grupo
            epcc23[valid_columns] = epcc23[valid_columns].fillna(0)

# Mostrar el total de casillas modificadas
print(f"Total de casillas modificadas en grupos NS/NC: {modified_cells_count}")
# Out:
# Total de casillas modificadas en grupos NS/NC: 75608

# %%
#pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)
epcc23.head()
# Out:
#     ID    Elevació  Mètode  SEXE  EDAT  I1  I2EA  I2EB  AJ1  I4  ...  \
# 0  100  674.941909       0     0     0   2     1    15    3   4  ...
# 1  201  674.941909       0     0     0   2     1    16    3   4  ...
# 2  202  674.941909       1     0     0   1     1    16    3   4  ...
# 3  303  674.941909       0     0     0   1     1    16    3   5  ...
# 4  501  674.941909       0     0     0   1     1    16    3  99  ...
#
#    AmbitTerritorial_COMARQUES GIRONINES  AmbitTerritorial_METROPOLITÀ  \
# 0                                 False                          True
# 1                                 False                          True
# 2                                 False                          True
# 3                                 False                          True
# 4                                 False                          True
#
#    AmbitTerritorial_PENEDÈS  AmbitTerritorial_PONENT  \
# 0                     False                    False
# 1                     False                    False
# 2                     False                    False
# 3                     False                    False
# 4                     False                    False
#
#    AmbitTerritorial_TERRES DE L'EBRE  GrandariaMunicipi_BARCELONA CIUTAT  \
# 0                              False                               False
# 1                              False                               False
# 2                              False                               False
# 3                              False                               False
# 4                              False                               False
#
#    GrandariaMunicipi_DE 10.001 A 50.000  GrandariaMunicipi_DE 2.001 A 10.000  \
# 0                                 False                                False
# 1                                 False                                False
# 2                                 False                                False
# 3                                 False                                False
# 4                                 False                                False
#
#    GrandariaMunicipi_FINS A 2.000  \
# 0                           False
# 1                           False
# 2                           False
# 3                           False
# 4                           False
#
#    GrandariaMunicipi_MÉS DE 50.000 - RESTA CATALUNYA
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                               True
#
# [5 rows x 530 columns]

# %%
# A ver cuántos NaN tengo ahora que he hecho el ajuste de las columnas agrupadas:
nan_percentage = epcc23.isna().mean() * 100

# Crear un DataFrame con la información
nan_info = pd.DataFrame({
    'Column': nan_percentage.index,
    'NaN_Percentage': nan_percentage.values
})

# Mostrar el DataFrame ordenado por el porcentaje de NaNs
nan_info_sorted = nan_info.sort_values(by='NaN_Percentage', ascending=False)
print(nan_info_sorted)
# Out:
#                                                 Column  NaN_Percentage
# 203                                             VJO13B       94.883608
# 507                                                CS6       92.507274
# 494                                                OR3       91.173618
# 184                                              VJO7D       90.809893
# 183                                              VJO7C       90.809893
# ..                                                 ...             ...
# 180                                            VJO7A#2        0.000000
# 179                                            VJO7A#1        0.000000
# 176                                            VJO6#99        0.000000
# 175                                            VJO6#95        0.000000
# 529  GrandariaMunicipi_MÉS DE 50.000 - RESTA CATALUNYA        0.000000
#
# [530 rows x 2 columns]

# %%
nan_info_nonzero = nan_info_sorted[nan_info_sorted['NaN_Percentage'] > 0]
print(nan_info_nonzero)
# Out:
#          Column  NaN_Percentage
# 203      VJO13B       94.883608
# 507         CS6       92.507274
# 494         OR3       91.173618
# 184       VJO7D       90.809893
# 183       VJO7C       90.809893
# ..          ...             ...
# 51   CA2A#value        0.218235
# 69    CA6#value        0.193986
# 30    PP3#value        0.169738
# 42     R3#value        0.169738
# 20     D3#value        0.048497
#
# [84 rows x 2 columns]

# %%
# Definir las columnas a verificar para NaN y rellenar con 99, 999 y 99999
columns_to_99 = ['I1', 'I4', "I3", "D1", "PP1", "R1", "CA1", "T3", "CA51", "IT2", "IT5", "VJO2", "VJO3#1", "VJO3", "VJO3#2", "VJO4#1", "VJO4#2", "VJO5", "VJ1", "VJ4", 
                 "VJ5", "VJO7", "VJO7B", "VJO8", "VJO9", "VJO10", "VJO12", "VJO13", "VJO13B", "M1", "M2", "CO1", "CO2", "CO10", "CN1", "CN1B", "CN10", "ES1", "ES2A", "ES10", 
                 "EX1", "EX10", "EX5", "EX10B", "EX11", "LL1", "LL1A", "LL3", "LL4", "LL6", "LL12", "LL13", "BI1", "LN6#8", "AS1", "LN6#7", "LN1", "LN3", "LN4", "LN5", "LN6#1", 
                 "LN6#2", "LN6#3", "LN6#4", "LN6#5", "LN6#6", "LN6#9", "Q10B", "OR2", "OR3", "G5", "OR4", "OR6", "OR7", "CS1", "CS2", "CS3", "CS6", "CS11", "CS12", "CS15A", 
                 "CS15", "CS21", "G2", "G2A"]

columns_to_999 = ["CO1A#2", "CO1A#1", "VJO11", "VJ1B", "CN1A", "G6", "G1", "LL13A", "LL2", "EX1A#1", "EX1A#2", "EX1A#3", "EX1A#4", "EX1A#5", "ES1A"]

columns_to_99999 = ["VJO7C"]

columns_to_3 = ["VJO6"]

# Contador de casillas modificadas
nan_to_99_modified_count = 0
nan_to_999_modified_count = 0
nan_to_99999_modified_count = 0
nan_to_3_modified_count = 0


# Rellenar con 99
for col in columns_to_99:
    if col in epcc23.columns:
        nan_count = epcc23[col].isna().sum()
        epcc23[col] = epcc23[col].fillna(99)
        nan_to_99_modified_count += nan_count

# Rellenar con 999
for col in columns_to_999:
    if col in epcc23.columns:
        nan_count = epcc23[col].isna().sum()
        epcc23[col] = epcc23[col].fillna(999)
        nan_to_999_modified_count += nan_count

# Rellenar con 99999
for col in columns_to_99999:
    if col in epcc23.columns:
        nan_count = epcc23[col].isna().sum()
        epcc23[col] = epcc23[col].fillna(99999)
        nan_to_99999_modified_count += nan_count

# Rellenar con 3
for col in columns_to_3:
    if col in epcc23.columns:
        nan_count = epcc23[col].isna().sum()
        epcc23[col] = epcc23[col].fillna(3)
        nan_to_3_modified_count += nan_count

# Mostrar el total de casillas modificadas
print(f"Total de casillas modificadas para NaN rellenadas con 99: {nan_to_99_modified_count}")
print(f"Total de casillas modificadas para NaN rellenadas con 999: {nan_to_999_modified_count}")
print(f"Total de casillas modificadas para NaN rellenadas con 99999: {nan_to_99999_modified_count}")
print(f"Total de casillas modificadas para NaN rellenadas con 3: {nan_to_3_modified_count}")

# Comprobar el porcentaje de NaNs por columna después de los cambios
nan_percentage = epcc23.isna().mean() * 100
nan_info = pd.DataFrame({
    'Column': nan_percentage.index,
    'NaN_Percentage': nan_percentage.values
})
nan_info_sorted = nan_info.sort_values(by='NaN_Percentage', ascending=False)
print(nan_info_sorted.head(20))
# Out:
# Total de casillas modificadas para NaN rellenadas con 99: 98925
# Total de casillas modificadas para NaN rellenadas con 999: 31914
# Total de casillas modificadas para NaN rellenadas con 99999: 3745
# Total de casillas modificadas para NaN rellenadas con 3: 2704
#          Column  NaN_Percentage
# 184       VJO7D       90.809893
# 487     LN7#4#3       81.595538
# 486     LN7#4#2       76.454898
# 484     LN7#4#0       72.672163
# 485     LN7#4#1       72.672163
# 488     LN7#4#9       27.376334
# 496    G5#value        2.546072
# 448   LN1#value        1.842871
# 445   AS2#value        1.818623
# 460   LN4#value        1.818623
# 458   LN3#value        1.697381
# 399  LL5A#value        1.624636
# 456   LN2#value        1.576140
# 197  VJO8#value        1.382153
# 83    CA5#value        1.236663
# 489   LN7#value        1.115422
# 116  VJO1#value        0.630456
# 177  VJO6#value        0.484966
# 51   CA2A#value        0.218235
# 69    CA6#value        0.193986

# %%
nan_info_nonzero = nan_info_sorted[nan_info_sorted['NaN_Percentage'] > 0]
print(nan_info_nonzero)
# Out:
#          Column  NaN_Percentage
# 184       VJO7D       90.809893
# 487     LN7#4#3       81.595538
# 486     LN7#4#2       76.454898
# 484     LN7#4#0       72.672163
# 485     LN7#4#1       72.672163
# 488     LN7#4#9       27.376334
# 496    G5#value        2.546072
# 448   LN1#value        1.842871
# 445   AS2#value        1.818623
# 460   LN4#value        1.818623
# 458   LN3#value        1.697381
# 399  LL5A#value        1.624636
# 456   LN2#value        1.576140
# 197  VJO8#value        1.382153
# 83    CA5#value        1.236663
# 489   LN7#value        1.115422
# 116  VJO1#value        0.630456
# 177  VJO6#value        0.484966
# 51   CA2A#value        0.218235
# 69    CA6#value        0.193986
# 30    PP3#value        0.169738
# 42     R3#value        0.169738
# 20     D3#value        0.048497

# %%
# 5. Manejo de strings únicos y celdas vacías
string_columns = epcc23.select_dtypes(include=['object']).columns

# Contador de casillas modificadas para strings
nan_to_na_modified_count = 0
dash_to_zero_modified_count = 0

for col in string_columns:
    # Contar y reemplazar NaNs por 'N/A'
    nan_count = epcc23[col].isna().sum()
    epcc23[col] = epcc23[col].fillna('N/A')
    nan_to_na_modified_count += nan_count

    # Contar y reemplazar '-' por '0'
    dash_count = (epcc23[col] == '-').sum()
    epcc23[col] = epcc23[col].replace('-', '0')
    dash_to_zero_modified_count += dash_count

# Mostrar el total de casillas modificadas para strings rellenadas con N/A y dashes reemplazadas con 0
print(f"Total de casillas modificadas para NaN rellenadas con N/A: {nan_to_na_modified_count}")
print(f"Total de casillas modificadas para '-' reemplazadas con 0: {dash_to_zero_modified_count}")
# Out:
# Total de casillas modificadas para NaN rellenadas con N/A: 766
# Total de casillas modificadas para '-' reemplazadas con 0: 78690

# %%
nan_percentage = epcc23.isna().mean() * 100
nan_info = pd.DataFrame({
    'Column': nan_percentage.index,
    'NaN_Percentage': nan_percentage.values
})
nan_info_sorted = nan_info.sort_values(by='NaN_Percentage', ascending=False)
print(nan_info_sorted.head())  # Mostrar las 20 primeras columnas con más NaNs
# Out:
#       Column  NaN_Percentage
# 184    VJO7D       90.809893
# 487  LN7#4#3       81.595538
# 486  LN7#4#2       76.454898
# 485  LN7#4#1       72.672163
# 484  LN7#4#0       72.672163

# %%
# 1. Ahora llenar los NaNs restantes con 0
epcc23.fillna(0, inplace=True)

# %%
nan_percentage = epcc23.isna().mean() * 100
nan_info = pd.DataFrame({
    'Column': nan_percentage.index,
    'NaN_Percentage': nan_percentage.values
})
nan_info_sorted = nan_info.sort_values(by='NaN_Percentage', ascending=False)
print(nan_info_sorted.head())  # Mostrar las 20 primeras columnas con más NaNs
# Out:
#      Column  NaN_Percentage
# 0        ID             0.0
# 348   EX7#6             0.0
# 362    EX11             0.0
# 361   EX10B             0.0
# 360  EX9#99             0.0

# %%
epcc23
# Out:
#           ID     Elevació  Mètode  SEXE  EDAT  I1  I2EA  I2EB  AJ1  I4  ...  \
# 0        100   674.941909       0     0     0   2     1    15    3   4  ...
# 1        201   674.941909       0     0     0   2     1    16    3   4  ...
# 2        202   674.941909       1     0     0   1     1    16    3   4  ...
# 3        303   674.941909       0     0     0   1     1    16    3   5  ...
# 4        501   674.941909       0     0     0   1     1    16    3  99  ...
# ...      ...          ...     ...   ...   ...  ..   ...   ...  ...  ..  ...
# 4119  399701  3120.629630       0     1     4   2     2    59    3   3  ...
# 4120  399902  3120.629630       0     1     4   1     2    57    3   4  ...
# 4121  400100  3120.629630       1     1     4   1     2    73    6   1  ...
# 4122  400103  3120.629630       0     1     4   2     2    77    3   2  ...
# 4123  400203  3120.629630       1     1     4   2     2    57    3   4  ...
#
#       AmbitTerritorial_COMARQUES GIRONINES  AmbitTerritorial_METROPOLITÀ  \
# 0                                    False                          True
# 1                                    False                          True
# 2                                    False                          True
# 3                                    False                          True
# 4                                    False                          True
# ...                                    ...                           ...
# 4119                                 False                         False
# 4120                                 False                         False
# 4121                                 False                         False
# 4122                                 False                         False
# 4123                                 False                         False
#
#       AmbitTerritorial_PENEDÈS  AmbitTerritorial_PONENT  \
# 0                        False                    False
# 1                        False                    False
# 2                        False                    False
# 3                        False                    False
# 4                        False                    False
# ...                        ...                      ...
# 4119                      True                    False
# 4120                      True                    False
# 4121                      True                    False
# 4122                      True                    False
# 4123                      True                    False
#
#       AmbitTerritorial_TERRES DE L'EBRE  GrandariaMunicipi_BARCELONA CIUTAT  \
# 0                                 False                               False
# 1                                 False                               False
# 2                                 False                               False
# 3                                 False                               False
# 4                                 False                               False
# ...                                 ...                                 ...
# 4119                              False                               False
# 4120                              False                               False
# 4121                              False                               False
# 4122                              False                               False
# 4123                              False                               False
#
#       GrandariaMunicipi_DE 10.001 A 50.000  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
# ...                                    ...
# 4119                                  True
# 4120                                  True
# 4121                                  True
# 4122                                 False
# 4123                                 False
#
#       GrandariaMunicipi_DE 2.001 A 10.000  GrandariaMunicipi_FINS A 2.000  \
# 0                                   False                           False
# 1                                   False                           False
# 2                                   False                           False
# 3                                   False                           False
# 4                                   False                           False
# ...                                   ...                             ...
# 4119                                False                           False
# 4120                                False                           False
# 4121                                False                           False
# 4122                                False                           False
# 4123                                False                           False
#
#       GrandariaMunicipi_MÉS DE 50.000 - RESTA CATALUNYA
# 0                                                  True
# 1                                                  True
# 2                                                  True
# 3                                                  True
# 4                                                  True
# ...                                                 ...
# 4119                                              False
# 4120                                              False
# 4121                                              False
# 4122                                               True
# 4123                                               True
#
# [4124 rows x 530 columns]

# %%
conditional_questions = [
    {"column": "I1", "trigger": [1, 2], "dependents": ["I2EB", 
                                                       "AJ1", 
                                                       "I4", 
                                                       "I3"]},
    {"column": "D1", "trigger": [1], "dependents": ['D2#1', "D2#2", "D2#4", "D2#99", 
                                                    'D3#1', "D3#2", "D3#3", "D3#99"]},
    {"column": "PP1", "trigger": [1], "dependents": ['PP0#1', 'PP0#2', 'PP0#3', 'PP0#99', 
                                                     'PP3#1', 'PP3#2', 'PP3#3', 'PP3#99']},
    {"column": "R1", "trigger": [1], "dependents": ['R2#1', 'R2#2', 'R2#3', 'R2#4', 'R2#5', 'R2#99', 
                                                    'R3#1', 'R3#2', 'R3#3', 'R3#99']},
    {"column": "CA1", "trigger": [1, 2, 3, 4, 5, 6], "dependents": ['CA2A#1', 'CA2A#2', 'CA2A#3', 'CA2A#4', 'CA2A#5', 'CA2A#6', 'CA2A#99', 
                                                    'T4#2', 'T4#3', 'T4#4', 'T4#5', 'T4#6', 'T4#7', 'T4#8', 'T4#11', 'T4#99',
                                                     "T3", 
                                                     "CA6#1", "CA6#2", "CA6#3", "CA6#4", "CA6#5", "CA6#6", "CA6#99",
                                                     "CA4#1", "CA4#2", "CA4#3", "CA4#4", "CA4#99", 
                                                     "CA51", 
                                                     "CA5#1", "CA5#2", "CA5#3", "CA5#4", "CA5#5", "CA5#6", "CA5#99"]},
    {"column": "IT2", "trigger": [1], "dependents": ['IT5']},
    {"column": "VJO5", "trigger": [1, 2, 3], "dependents": ["VJ2#1", "VJ2#2", "VJ2#3", "VJ2#4", "VJ2#5", "VJ2#6", "VJ2#7", "VJ2#8", "VJ2#9", "VJ2#10", "VJ2#99"]},
    {"column": "VJO5", "trigger": [4, 5], "dependents": ["VJO1#1", "VJO1#2", "VJO1#3", "VJO1#4", "VJO1#5", "VJO1#6", "VJO1#7", "VJO1#8", "VJO1#9", "VJO1#10", "VJO1#11", "VJO1#99", 
                                                        "VJ1B", 
                                                        "VJ3#1", "VJ3#2", "VJ3#3", "VJ3#4", "VJ3#5", "VJ3#6", "VJ3#7", "VJ3#8", "VJ3#99", 
                                                        "VJ4", 
                                                        "VJ5", 
                                                        "VJ6#1", "VJ6#2", "VJ6#3", "VJ6#4", "VJ6#5", "VJ6#6", "VJ6#7", "VJ6#99", 
                                                        "VJ7#1", "VJ7#2", "VJ7#3", "VJ7#4", "VJ7#5", "VJ7#6", "VJ7#7", "VJ7#8", "VJ7#9", "VJ7#10", "VJ7#11", "VJ7#99", 
                                                        "VJO6" , "VJO6#1", "VJO6#2", "VJO6#3", "VJO6#4", "VJO6#5", "VJO6#6", "VJO6#7", "VJO6#95", "VJO6#99", # ????
                                                        "VJO7"]}, # VJO5 DE EXCEL / CSV PARECE SER P18 EN EL PDF
    {"column": "VJO7", "trigger": [1], "dependents": ['VJO7A#1', 'VJO7A#2', 'VJO7A#99', 
                                                      'VJO7B']},
    {"column": "VJO8", "trigger": [1], "dependents": ['VJO8#1', 'VJO8#2', 'VJO8#3', 'VJO8#4', 'VJO8#5', 'VJO8#6', 'VJO8#7', 'VJO8#8', "VJO8#9", "VJO8#95", "VJO8#99"]},
    {"column": "VJO7B", "trigger": [1], "dependents": ['VJO7C', 
                                                       'VJO7D']},
    {"column": "I3", "condition": lambda x: x != 0, "dependents": ['VJO9', 
                                                                   'VJO10', 
                                                                   'VJO11', 
                                                                   'VJO12', 
                                                                   'VJO13']},
    {"column": "VJO13", "trigger": [1], "dependents": ['VJO13B']},
    {"column": "M1", "trigger": [1], "dependents": ['M2', 
                                                    "M3#1", "M3#2", "M3#3", "M3#4", "M3#5", "M3#6", "M3#7", "M3#99", 
                                                    "M4#1", "M4#7", "M4#9", "M4#10", "M4#11", "M4#13", "M4#18", "M4#19", "M4#99", 
                                                    "M5#1", "M5#2", "M5#3", "M5#4", "M5#5", "M5#6", "M5#7", "M5#8", "M5#9", "M5#99"]},
    {"column": "M1", "trigger": [0], "dependents": ['M7#1', 'M7#2', 'M7#3', 'M7#4', 'M7#5', 'M7#6', 'M7#7', 'M7#8', 'M7#9', 'M7#10', 'M7#11', 'M7#99']},
    {"column": "CO1", "trigger": [1], "dependents": ['CO1A#1', "CO1A#2",
                                                     'CO3#1', 'CO3#2', 'CO3#3', 'CO3#4', 'CO3#5', 'CO3#6', 'CO3#7', 'CO3#99', 
                                                     "CO9#1", "CO9#7", "CO9#9", "CO9#10", "CO9#11", "CO9#13", "CO9#18", "CO9#19", "CO9#99", 
                                                     "CO10"]},
    {"column": "CO1A#2", "condition": lambda x: x > 0, "dependents": ['CO2']},
    {"column": "CO1", "trigger": [0], "dependents": ['CO7#1', 'CO7#2', 'CO7#3', 'CO7#4', 'CO7#5', 'CO7#6', 'CO7#7', 'CO7#8', 'CO7#9', 'CO7#10', 'CO7#99']},
    {"column": "CN1", "trigger": [1], "dependents": ['CN1A', 
                                                     "CN2#1", "CN2#2", "CN2#3", "CN2#4", "CN2#5", "CN2#6", "CN2#99", 
                                                     "CN1B", 
                                                     "CN5#1", "CN5#2", "CN5#3", "CN5#4", "CN5#5", "CN5#6", "CN5#9", "CN5#10", "CN5#11", "CN5#12", "CN5#13", "CN5#99", 
                                                     "CN10"]},
    {"column": "CN1", "trigger": [0], "dependents": ['CN6#1', 'CN6#2', 'CN6#3', 'CN6#4', 'CN6#5', 'CN6#6', 'CN6#7', 'CN6#8', 'CN6#9', 'CN6#88', 'CN6#99']},
    {"column": "ES1", "trigger": [1], "dependents": ['ES1A', 
                                                     "ES2A", 
                                                     "ES3#1", "ES3#2", "ES3#3", "ES3#4", "ES3#5", "ES3#6", "ES3#7", "ES3#99", 
                                                     "ES10"]},
    {"column": "ES1", "trigger": [0], "dependents": ['ES6#1', 'ES6#2', 'ES6#3', 'ES6#4', 'ES6#5', 'ES6#6', 'ES6#7', 'ES6#8', 'ES6#9', 'ES6#88', 'ES6#99']},
    {"column": "EX1", "trigger": [1], "dependents": ['EX1A#1', 'EX1A#2', 'EX1A#3', 'EX1A#4', 'EX1A#5', 
                                                     "EX10", 
                                                     "EX5"]},
    {"column": "EX1", "trigger": [0], "dependents": ['EX7#1', 'EX7#2', 'EX7#3', 'EX7#4', 'EX7#5', 'EX7#6', 'EX7#7', 'EX7#8', 'EX7#9', 'EX7#88', 'EX7#99']},
    {"column": "EX1A#1", "condition": lambda x: x > 0, "dependents": ['EX9#1', 'EX9#2', 'EX9#3', 'EX9#4', 'EX9#5', 'EX9#6', 'EX9#99',
                                                                      "EX10B", 
                                                                      "EX11", 
                                                                      "EX13#1", "EX13#1", "EX13#1", "EX13#1", "EX13#1", "EX13#1", "EX13#1", "EX13#1", "EX13#99"]},
    {"column": "LL1", "trigger": [1], "dependents": ['LL1A', 
                                                     "LL2", 
                                                     "LL3", 
                                                     "LL4", 
                                                     "LL5#2", "LL5#3", "LL5#4", "LL5#5", "LL5#6", "LL5#7", "LL5#8", "LL5#9", "LL5#10", "LL5#11", "LL5#99", 
                                                     "LL5A#1", "LL5A#2", "LL5A#3", "LL5A#4", "LL5A#5", "LL5A#6", "LL5A#7", "LL5A#8", "LL5A#9", "LL5A#10", "LL5A#99", 
                                                     "LL6", 
                                                     "LL12"]},
    {"column": "LL1", "trigger": [0], "dependents": ["LL11#11", "LL11#12", "LL11#2", "LL11#3", "LL11#4", "LL11#7", "LL11#13", "LL11#9", "LL11#16", "LL11#99",]},
    {"column": "LL1", "condition": lambda x: (x > 0) & (x < 99), "dependents": ["LL13"]},
    {"column": "LL13", "trigger": [1], "dependents": ["LL13A"]},
    {"column": "BI1", "trigger": [1, 2, 3, 4, 5, 6], "dependents": ["BI2#1", "BI2#2", "BI2#3", "BI2#4", "BI2#99"]},
    {"column": "BI1", "condition": lambda x: (x > 0) & (x < 7), "dependents": ["BI3#1", "BI3#2", "BI3#3", "BI3#5", "BI3#6", "BI3#7", "BI3#8", "BI3#10", "BI3#99", 
                                                                               "LN6#8"]},
    {"column": "AS1", "trigger": [1, 2], "dependents": ["AS2#1", "AS2#2", "AS2#3", "AS2#4", "AS2#5", "AS2#6", "AS2#7", "AS2#8", "AS2#9", "AS2#10", "AS2#11", 
                                                        "AS2#16", "AS2#17", "AS2#99",
                                                        "LN6#7"]},
    {"column": "OR2", "trigger": [3], "dependents": ["G6"]},
    {"column": "OR2", "trigger": [2], "dependents": ["OR3"]},
    {"column": "CS1", "trigger": [1], "dependents": ["CS2"]},
    {"column": "CS2", "trigger": [1], "dependents": ["CS3"]},
    {"column": "CS1", "trigger": [2], "dependents": ["CS6"]},
    {"column": "CS1", "trigger": [3], "dependents": ["CS11"]},
    {"column": "CS1", "trigger": [4, 5], "dependents": ["CS12"]},
    {"column": "CS15A", "condition": lambda x: x != 1, "dependents": ["CS15", "CS21"]},
    {"column": "I4", "trigger": [3, 4, 5, 6], "dependents": ["G2"]},
    {"column": "I4", "trigger": [1, 2], "dependents": ["G2A"]},
]

# Crear un diccionario para las nuevas columnas
new_columns = {}

for q in conditional_questions:
    column = q["column"]
    if 'trigger' in q:
        triggers = q['trigger']
        for dependent in q['dependents']:
            if dependent in epcc23.columns:
                new_column_name = f'answered_{dependent}'
                new_columns[new_column_name] = np.where(epcc23[column].isin(triggers), epcc23[dependent], np.nan)
    elif 'condition' in q:
        cond_function = q['condition']
        for dependent in q['dependents']:
            if dependent in epcc23.columns:
                new_column_name = f'answered_{dependent}'
                new_columns[new_column_name] = np.where(cond_function(epcc23[column]), epcc23[dependent], np.nan)

# Añadir todas las nuevas columnas al DataFrame de una vez
new_columns_df = pd.DataFrame(new_columns, index=epcc23.index)
epcc23 = pd.concat([epcc23, new_columns_df], axis=1)

# %%
# 7. Marcar similitud o paralelismo entre columnas
# Definir los motivos comunes
motivos_comunes = {
    'Manca de temps': ['VJ2#1', 'M7#1', "CO7#1", "CN6#1", "ES6#1", "EX7#1", "LL11#11"],
    'Responsabilitats familiars': ['VJ2#2', 'M7#2', "CO7#2", "CN6#2", "ES6#2", "EX7#2", "LL11#12"],
    'Manca d’interès': ['VJ2#3', 'M7#4', "CO7#4", "CN6#4", "ES6#4", "EX7#4", "LL11#3"],
    'Manca d’informació': ['VJ2#4', 'M7#5', "CO7#5", "ES6#5", "EX7#5", "LL11#4"],
    'Problemes de salut': ['VJ2#5', 'M7#7', "CO7#6", "CN6#5", "ES6#6", "EX7#6", "LL11#7"],
    'No tenir amb qui': ['VJ2#6', 'M7#8', "CO7#7", "CN6#6", "ES6#7", "EX7#7", "LL11#13"],
    'Manca d’oferta': ['VJ2#7', 'M7#9', "CO7#8", "CN6#7", "ES6#8", "EX7#8", "LL11#9"],
    'Preu': ['VJ2#8', 'M7#3', "CO7#3", "CN6#3", "ES6#3", "EX7#3", "LL11#2"],
    'Dificultats d’accessibilitat': ['VJ2#9', 'M7#10', "CO7#9", "CN6#9", "ES6#9", "EX7#9"],
    'Altres': ['VJ2#10', 'M7#11', "CO7#10", "CN6#88", "ES6#88", "EX7#88", "LL11#16"],
    "NS/NC": ["VJ2#99", "M7#00", "CO7#99", "CN6#99", "ES6#99", "EX7#99", "LL11#99"],
    "Baixa qualitat": ["M7#6"],
    "Ho faig per una altra via": ["CN6#8"]
}

# Crear nuevas columnas para cada motivo común y inicializarlas en 0
for motivo in motivos_comunes:
    epcc23[f'{motivo}_total'] = 0

# Actualizar las nuevas columnas basándose en los motivos existentes
for motivo, cols in motivos_comunes.items():
    for col in cols:
        if col in epcc23.columns:
            epcc23[f'{motivo}_total'] += epcc23[col]

# %% [markdown]
# ##### Al menos de momento voy a dejar identificadas y apartadas las columnas con string que tienen valores no estructurados

# %%
# Identificar las columnas que terminan en #value
value_columns = [col for col in epcc23.columns if col.endswith('#value')]

# Crear un DataFrame separado para estas columnas
value_df = epcc23[value_columns]

# Eliminar estas columnas del DataFrame principal
epcc23 = epcc23.drop(columns=value_columns)

# %%
# Ver los valores únicos para cada una de las columnas #value
for col in value_df.columns:
    print(f"Valores únicos para la columna {col}:")
    print(value_df[col].unique())
    print("\n")
# Out:
# Valores únicos para la columna D3#value:
# ['0' '-ÁNGLES' 'INGLÉS' 'INGLÉS,JAPONÉS' 'N/A' 'ANGLÈS' 'ANGLES' '-INGLES'
#  'ARABE' 'INGLES' 'ALEMANY, ANGLÈS' 'ALEMANY' 'ANGELS' 'HOLANDES, INGLES'
#  'ÁRABE' 'ITALIANO E INGLÉS' 'ENGLISH' 'PORTUGUÉS E INGLES'
#  'ANGLÈS, ITALIÀ' 'VASC, ANGLES' 'ANGLÉS , FRANCÉS I ITALIÀ'
#  'INGLES, ALEMAN' 'FRANCES INGLES' 'URDU' 'ITALIANO' 'ANGLÉS' 'FRANCÉS'
#  '-ANGLES' 'ALEMANY I INGLÉS' 'EN INGLES BBC NEWS' 'FRANCÉS, ANGLÈS'
#  'FRANCES' 'ALEMÁN, INGLÉS' 'GALLEC' 'INGLÉS Y FRANCÉS' 'RUSO'
#  '-INGLES Y FRANCES' 'PORTUGUÉS' 'BÚLGARO' 'ALEMÁN'
#  'ITALIÀ, ANGLÈS, FRANCÈS, ALEMANY' 'CHINO MANDARÍN, PEQUINES Y RUSO'
#  'FRANCÈS' 'UKRANIANO, RUSO' 'ITALIANO - INGLES' 'SUECO'
#  'ALEMANY FRANCÈS ANGLÈS' 'GALLEGO' 'RUMANO' 'ÁRABES' 'ANGLES I FRANCES'
#  'ÁRABE ,INGLES' 'PORTUGUES' 'FRANCÉS Y INGLÉS' 'ANGLÉS I POLONÉS']
#
#
# Valores únicos para la columna PP3#value:
# ['0' 'INGLES' 'ANGLÉS' 'INGLÉS' 'ANGLÈS' 'ANGLES' 'INGLES, GALLEGO' 'N/A'
#  'FRANCES' 'ANGLE' '-INGLES' 'FRACÈS I ANGLES' 'ANGLES I FRANCES'
#  'ALEMANY, ANGLÈS' 'ANGLÈS I FRANCÈS' 'HOLANDES, INGLES' 'ÁRABE'
#  'ITALIANO E INGLÉS' 'MANDARIN' 'VASC, ANGLES' 'ANGLÉS, FRANCÉS I ITALIÀ'
#  'FRANCES INGLES' 'INGLÉS, FRANCÉS, GALLEGO' 'INGLES, TVI'
#  'INGLÉS ITALIANO' 'ITALIANO' 'ANGLÈS, EUSKERA' 'ANGL?S' 'FRANCÉS'
#  'INGLES, HOLLANDES' 'ANGLES, ITALIA, FRANÇES' 'ALEMANY' 'INGLE, FRANCES'
#  'ANGÈS' 'INGLES, JAPONES' 'FRANCÈS' 'ANGLÈS, ITÀLIA' 'ITALIÀ' 'ALEMÁN'
#  'ALEMÁN, INGLÉS' 'ALEMANY, ANGLÉS, ITALIÀ' '-ANGLÈS I ÀRAB' 'ANGÉS'
#  'RUSO' 'ALEMAN, INGLES' 'ARABE' 'ENGLISH' 'INGLES Y FRANCES'
#  'ITALIANO Y INGLÉS' 'INGLES, UCRANIANO' 'ANGLÈS / FRANCÈS' 'BÚLGARO'
#  'ITALIÀ, ANGLÈS, FRANCÈS.' 'CHINO PEQUINES, MANDARÍN Y RUSO'
#  'ALEMAN INGLES' 'ITALIANO - INGLES' 'SUECO' 'INGLÉS, PORTUGUÉS, JAPONÉS'
#  'GALLEGO E INGLÉS' 'RUMANO' 'ENGLISH, FRENCH' 'ÁRABES'
#  'ITAMBÉ EN `ANGLÈS' 'ÁRABE ,INGLES' 'INGLÉS, PORTUGUÉS' 'ARAB'
#  'ANGLÈS, FRANCÈS' 'FRANCÈS I ANGLÈS' 'ANGLÈS, FRANCES' 'INGLÈS'
#  'HOLANDÉS' 'FRANCÉS, ÁRABE,' 'FRANCÉS Y INGLÉS' 'ANGELESI FRANCES'
#  'ANGLÉS I POLONÉS' 'INGLES3']
#
#
# Valores únicos para la columna R3#value:
# ['0' 'INGLÉS' 'JAPONÉS' 'INGLES' 'ANGLÈS' 'ANGLÉS' 'ANGLÈS, ALEMANY'
#  'ITALIANO' 'ITALIA' 'ANGLÈS, ITALIÀ' 'FRANCES' 'ANGLES' 'N/A'
#  'ITALIANO, FRANCÉS, INGLÉS, COREANO, ETC' 'EN ANGLÉS' 'ENGLISH'
#  'INGLES, ALEMAN' '-ARABE' 'FRANCÉS' 'INGLES Y FRANCES' 'FRANCES Y INGLÉS'
#  'ITALIÀ, ANGLÈS, FRANCÈS I ALEMANY' 'CHINO MANDARÍN, PEQUINES Y RUSO'
#  'ALEMAN INGLES' 'RUSO' 'GALLEGO' 'INGELS' 'FRANCIA' 'ANGLÈS/HOLANDÈS'
#  'FRANCÈS' 'I TAMBÉ ANGLÈS I FRANCÈS' 'ARABE' 'ARANÉS']
#
#
# Valores únicos para la columna CA2A#value:
# ['0' 'PIRATEJANT' 'N/A' 'DVD' 'TIKTOK, REELS' 'BLU-RAY, DVD' 'SPOTIFY'
#  'IPTV' 'ESCUELA' 'TIKTOK, INSTAGRAM' '-INTERNET ARABE' 'XARXES SOCIALS'
#  'SCOPUS' 'APLICACION MODEL CANVAS' 'INSTAGRAM Y OTRAS REDES SOCIALES'
#  'EBOX' 'TWICH' 'ORDINADOR I MOVIL' 'TWITER'
#  'CARTA DOMICAL DE NUESTRO ARZIBISPO DE TARRAGONA,AUDIENCIAS DE SANTO PADRE PAPA FRANCISCO'
#  'PODCASTS' 'TWITCH' 'CDS PRESTADOS DE LA BIBLIOTECA O POR ALGÚN AMIGO.'
#  '-TIENE UN APARATO PARA VER EL FUTBOL' 'APPS XX.SS']
#
#
# Valores únicos para la columna CA6#value:
# ['0' 'PORTUGUES' 'JAPONÉS' 'UCRANIA' 'PORTUGUÊS' 'JAPONES' 'JAPONÈS'
#  'ITALIANO' 'EN ITALIANO' 'ARABE' 'GALLEGO' 'N/A' 'ÀRAB' 'KOREÀ' 'EGIPCI'
#  'ÁRABE' 'URDU, HINDU' 'PERSA' 'ITALIÀ' 'HOLANDES' 'ITALIANO E INGLÉS'
#  'PORTUGUÉS' 'BEREBER' 'NORUEG, FINLANDÉS,' 'INGLES' 'RUSO' '-JAPONES'
#  'EUSKERA' 'HOLLANDES' 'ITALIÁ' 'MALLORQUIN' '-JAPONÉS' 'CHINO'
#  'JAPONÉS, COREANO, ITALIANO, ZULÚ, ETC' '-ARABE' 'COREANO'
#  'COREANO, JAPONÉS Y CHINO' 'JAPONÉS, CHINO' 'TAGALOG'
#  'LLLLENGUES ASIATIQUES' 'COREÀ' 'GALLEC' 'JAPONÉS Y COREANO'
#  'CHINO, COREANO Y JAPONÉS' 'JAPONÈS, COREÀ' 'ITALIA' 'RUMANO' '-CHINO'
#  'URDU' 'UCRANIANO' 'BÚLGARO' 'TURCO' 'TURC' 'DANÉS'
#  'CHINO MANDARÍN, PEQUINES Y RUSO' 'UKRAINÈS' 'LSC I LSE' 'SUECO'
#  'UCRAINÈS, RUS' 'ÁFRICANA' 'ARABGE' 'EN ORIGINAL' 'INDIA'
#  'COREÀ, TAILANDÉS,' 'LATINO' 'JAPONÈS SUBSTITULAT' 'ROMANIA' 'BASC'
#  'ARABI' 'ARAB' 'FRANCES' 'COREÀ I JAPONÈS' 'JAPO' 'HINDI PUNJABI'
#  'JAPONÉS, PORTUGUÉS, RUSO, ITALIANO, CHINO, COREANO ETC' 'BÚLGAR'
#  'XINÉS I COREÀ' 'RUMANIA' 'COREA']
#
#
# Valores únicos para la columna CA5#value:
# ['0' 'JAPONES' 'N/A' 'JAPONÉS' 'ESPAÑOL,RUSO' 'JAPONÈS' 'ITALIANO' 'CHINO'
#  'COREÀ' 'JPN' 'TURC' 'ÁRABE' 'ITALIÀ' 'PORTUGUÉS' 'PORTUGUES' 'NORUEG'
#  'RUSO' 'JAPONÈS I COREÀ' 'COREANO' 'PUNJABI' 'ARABE'
#  'ITALIANO, COREANO, CHINO, ETC' 'KOREA' 'TAILANDÈS' 'ÁRAB' 'TAGALOG'
#  '-JAPONES Y COREANO' 'ÀRAB' 'HINDÚ' 'MANDARIN' 'ITALIANA' 'URDU'
#  'COREANO , TAILANDES' 'DANÉS' 'TURCO' 'CHINO MANDARÍN, PEQUINES Y RUSO'
#  'COREÁ, JAPONÉS, XINÈS...' 'SUECO' '-ITALIANO' 'INDIA' 'TAILANDES'
#  '-RUMANO' 'CASTILLA' 'RUMANO' 'ROMANIA' 'ARABIC' 'ARBI' 'JAPONESA' 'ARAB'
#  'TURCA' 'COREANA' 'UCRANIA' '-JAPONES' 'ITALIA']
#
#
# Valores únicos para la columna VJO1#value:
# ['0' 'N/A' 'APRENDIZAJE' 'DEGRADACION'
#  'NUNCA HEMOS TENIDO TV EN CASA POR DECISION NO POR TEMAS ECONOMICOS, DE MODO QUE NUNCA JUEGO A NADA. LO QUE HAGO ES APRENDER DE FORMA AUTODIDACTA Y ESCUCHAR MUSICA. TODO EN INGLES.'
#  'ESFORÇ I APRENENTATGE' 'AVENTURA' 'PERDUA DE TEMPS' 'PERDIDA DE TIEMPO'
#  '-HISTORIA' 'PERDIDA TIEMPO' 'ABURRIMENT' 'VIDEOJUEGO' 'CONCENTRACIÓN'
#  'ACIDEZ' 'ARCADE' 'ANTIGUO' 'INFANTIL' 'CUANDO ERA JOVEN'
#  'NO ME INTERESAN LOS VIDEOJUEGOS' 'OCIO' 'NO JUGO' 'RES'
#  'SIMULADOR DE AVIONES COMERCIALES' 'INDIFERENCIA' 'ME REPELE'
#  'NO LE GUSTA' '-ELS DETESTA' 'EDUCATIUS' 'HIJOS'
#  'QUE FATIDIA A LOS NIÑOS PEQUENOS' 'PORQUERIA' 'JUVENTUD'
#  'NO EN TINC CAP EXPERIÈNCIA' 'ELS NETS' 'ABURRIMIENTO' 'PERDER TIEMPO'
#  'APRENDER INGLES, O COSTUMBRES' 'INDIFERÈNCIA'
#  'APRENDIZAJE DE HABILIDADES Y SUPERACIÓN' 'HOBY' 'JOIC' 'ABSSORCIO TEMPS'
#  'ABURRIMEINTO' 'PLAYSTATION' 'PÉRDIDA DE TIEMPO' 'HOMES' 'ASOCIAL'
#  'GENTE JUGANDO' 'ABORRIMENT' 'NO LE GUSTAN' 'LALGUN JUEGO' 'EN SU HIJA'
#  'ADOLESCENTES' 'ATRACCION' 'ADOLESCENTS' 'HISTORIAS' 'AGILIDAD MENTAL'
#  'NO LE DICE NADA, NO LE INTERESAN' 'NI FU NI FA' 'ADOLESCÈNCIA ALARMA'
#  'TRASTORNO' 'NO ME GUSTA' 'INFANT' 'NO JUEGO VIDEOJUEGOS'
#  'APRENENTATGE, ENTRENAMENT PER A LA SUPERACIÓ DE LA FRUSTRACIÓ'
#  'AVERSIÓ ALS VIDEOJOCS' 'JUEGOS' 'ELS SEUDS NETS' 'EDUCACIÓN' 'MI HIJO'
#  'COMPETENCIA' 'NO ME INTERESAN Y NI CONOZCO' 'ESTAFA'
#  'NO UTILIZO VIDEOJUEGOS' 'ALGO MALO QUE NO ES BUENO' 'GASTO'
#  'PERDUA DE TEMPS DE LA  TEVA VIDA' 'PERDRE EL TEMPS'
#  "TOT DEPÈN DEL VIDEOJOC I DE L'ÚS QUE  L'USUARI EN FA DEL MATEIX . JO PERSONALMENT NO HE JUGAT MAI EN LA MEVA VIDA."
#  'PERDIDA DE TEMPS' 'OBSESSIO' 'NO ENTENC RES'
#  'ES MOLT GRAN I NO SAP LO QUE ES' 'PÈRDUA DE TEMPS' 'OCI'
#  'JUGAR CON GENTE' 'PERDIDAS' 'NADA' 'PER CANALLA' '-PERDIDA DE TIEMPO'
#  'SOLEDAT' 'NO ES INTERESANTE' 'PERDER EL TIEMPO' 'APRENENTATGE' 'PEREZA'
#  'DEPRESSIÓ' 'DORMIR' 'ANIMACION' 'PERDIDA DE TIEMPO.'
#  'MODERACIÓ (CREC QUE FONAMNETAL PER A LES ACTIVITATS DE LLEURE)'
#  'PROCASTINACIÓ' 'HOBBY' 'UN COME COCOS' 'JOCS DE TAULA' 'NO LHI AGRADEN'
#  'RPG, MULTIJUGADOR, ANIME, ARCADE ETC' 'ADOLESCÈNCIA'
#  'NO LI AGRADEN I NO ES BENEFICOS' 'JUGAR' 'X- BOX, PLAY 3 O 4'
#  'TRABAJO EN EQUIPO' 'FILLS' 'FORNITE'
#  'BUTACA ERGONOMICA , PANTALLA I PASAR-SO BE' 'TOT MENYS CULTURA'
#  'DEPENDE DEL CONTENIDO' 'TIENEN QUE JUGAR CUANDO SEAN MAS MAYORES'
#  'CONSOLA, MOBIL' 'ESTRÉS' 'IDIOTEZ']
#
#
# Valores únicos para la columna VJO6#value:
# ['0' 'MASCLES' 'PERSONES DE GENERE' 'DONES NO MALTRACTADES'
#  'NO HI HA GAIRE REPRESENTACIÓ LGBT+' 'N/A' 'DEPENDENTE SON DIFERENTES'
#  'DE AVENTURAS'
#  'DE TODO. SI ALGO NO HAY EN LOS VIDEOJUEGOS DE GRANDES EMPRESAS ES DIVERSIDAD.'
#  'LGTB' 'DONES NO HETERONORMATIVES.'
#  'MÉS REPRESENTACIONS DEL COLECTIU LGTB'
#  'CULTURALS / SEXUALS. NOMÉS SURTEN REPRESENTATS PERSONAGES QUE COMPLEIXEN AMB ELS ESTERIOTIPS.'
#  'FALTA REPRESENTACIÓN DE MINORIAS ES MUCHA COSA NO PODRIA DECIR'
#  'MARIO BROS'
#  'EN LOS JUEGOS DE RALLYS(COCHES) NO HAY PILOTOS FEMENINOS Y TAMPOCO EN MOTOGP'
#  'MES VARIETAT DE PERSONATGES I GENERES' 'TRANS'
#  'DIFERENTS TIPUS DE SEXUALITAT.'
#  "HA MILLORAT MOLT, ENCARA FALTA, JOCS COM BALDUR'S GATE 3 HO FAN MOLT BÉ INCLOENT-HI PERSONATGES NO-BLANCS, NO-HOMES, I DE TOT TIPUS"
#  'PODRIA SER MAS ORGANICO' 'LGBT' 'MES DONES' 'NENS AMB DISCAPACITATS'
#  'PERSONATJES HISTORICS, CIVILITZACIONS ANTIGUES, NO TANTA FICCIÓ'
#  'PUES DE TODO UN POCO, MÁS CUANDO TE TE PUEDES PERSONALIZAR'
#  'GENERALMENT LES DONES ES SEXUALITZEN I ELS HOMES ES REPRESENTEN COM FORTS ELS MILLORS, ,ETC'
#  'LGTB, ASIATICS' 'PERSONATGES DEL COLECTIU LGTB'
#  'MAS GENEROS QUE NO SOLO DOS' 'DE GENERE'
#  'DIVERSITAT RACIAL. PERSONATGES FEMENINS'
#  'SI EXISTE VARIEDAD, PERO EN GENERAL AUN NO ESTÁN PRESENTES EN GRANDES FRANQUICIAS'
#  'PERSONATGES FEMENINS NO SEXUALITZATS' 'PERSONAJES LGTBIQ'
#  'DONES SENSE SEXUALITZAR'
#  "LÁS 'BÁSICAS' (HETERO, BISEXUAL O GAY) NO INDAGA EN EL ESPECTRO O DIFERENTES FORMAS EJ. RELACIONES POLIAMOROSAS O PERSONAS NO BINARIAS"
#  'EN MUCHOS JUEGOS EXISTE VARIEDAD, PERO FALTA BASTANTE DEPENDIENDO DEL JUEGO'
#  'MUJER REAL' 'QUEER' 'TTRANSGENERO'
#  'PERSONA NO BINARIAS,NEGROS,ASIATICAS,PERSONAS CON DEFICIENCIA'
#  'INCLUSIO DE GENERE' 'PERSONAJES DE CULTURAS DIFERENTES'
#  'LE FALTAN MAS GENEROS' 'ROLS DE GÈNERE FLUIDS, MENYS SEXISME'
#  "MAJOR PAPER DE LA DONA , NO HI HAURIA D'HAVER DIFERENCIES ENTRE SEXES"
#  'EDAT AVANÇADA' 'MUJERES, ETNIAS NO CAUCASICAS' 'MENOS VIOLENCIA'
#  'LGTBIQ+'
#  'AMPLIO EL ABANICO QUE NO SEA UNICAMENTE CHICO O CHICA LOS GENEREOS RELACIONADOS CON LA VIDA'
#  'MAS PAPEL DE LA MUJER' 'LA DIVERSITAT DE GENERE'
#  'ALGO MAS DIVERSO, MAS EN LINEA CON LA ACTUALIDAD' 'DIFERENTS RACES'
#  'GENT DE DIFERENTS CONTINENTS, SEXUALITATS, FORMA DE FÍSICS.' 'UNCHARTER'
#  'EL TEMA DEL RACISMO' 'GAIREBÉ TOTS' 'GENERO NEUTRO' 'LGTBI'
#  'MUJERES EN JUEGOS DE LUCHA, DE COCHES...'
#  'NOIS TRAVESTIS, RELIGIOSOS, ALTRES CULTURES'
#  'NO HI HA REPRESENTACIÓ DE VARIETAT CULTURALS NI SEXUALS.'
#  'QUE SEAN MAS AMBIGUOS O QUE NO MARQUEN TANTO EL HOMBRE O MUJER'
#  'CULTURES, DIVERSITAT DE GÉNERE, FEMINISME, DIVERSITAT DE COSOS REALS'
#  'NO HAY CULTURA EN LOS VIDEOJUEGOS' 'QUEER,,LGTBI' 'LIDERS FEMENINES'
#  'QUE SEAN DISCRETOS CON LOS PERSONAJES AUNQUE LOS RESPESTE'
#  'VARIETAT SOBRETOT EN ELS ESTEREOTIPS DE GENERE'
#  'EN FUNCIÓ DE LA.COMPLEXITAT DEL JOC. QUANT MÉS SIMPLES SÓN, MÉS ESTÈTICS.']
#
#
# Valores únicos para la columna VJO8#value:
# ['CARRERAS' 'FÚTBOL' '0' 'PREMIER LEAGUE, LALIGA, LIGA ASOBAL DE HANDBALL'
#  'EN TORNEOS DE BASEBALL, ME INTERESAN TORNEOS DE JUEGOS DE LUCHA AL ESTILO DE EVO'
#  'N/A' 'FIFA, FORNITE (?)' 'TORNEOS DE FIGHTER Z' '-FIFA'
#  'LEC, LVPS I ELS WORLDS DE LOL' 'CLASIFICATORIAS MUNDIAL GRAN TURISMO'
#  'FORTNITE' 'LIGAS DE F1' 'WORLDS 2023'
#  'TORNEOS DE MARIO KART WII, SPEEDRUNS OMORI, COMPETICIONES CLONE HERO'
#  'FORTNITE COMPETITIVE' 'FUTBOL'
#  'PARTICIPÉ EN UN EVENTO DE LEAGUE OF LEGENDS' 'ARMWRESTLING'
#  'TORNEJOS DE LLUITA I TRETS' 'LOL ESPORTS (LEC, MSI, WORLDS...)'
#  'COMMUNITAT SPEEDRUNNER DE DIVERSOS JOCS COM RESIDENT EVIL O DARK SOULS'
#  'DESCENSO/ ENDURO MTB' 'FNCS' 'PING PONG, KARATE'
#  'HE JUGAT DIVERSOS TORNEJOS DE ROCKET LEAGUE' 'GRAN TURISMO GT' 'HANDBOL'
#  'PREMIER VALORANT' 'FIFA' 'ELALIGA SANTANDER' 'VALORANT'
#  'LOL WORLDS, OW WORLD CUP...' 'UEFN...........FORMULA UNA'
#  'COMPETICION MUNDIAL' 'F1, BOXA' '.' 'BRAWL STARS' 'BOXEO'
#  'LEC I ELS WORLDS (LOL)' 'TORNEOS ONLINE' '-COUNTER STRIKE'
#  'CIRCUITO TORMENTA VALORANT' 'IESPORTS (LEAGE OF LEGENDS)' 'LECK'
#  'ROCKET LEAGUE' 'OPEN MEDITERRANEO ARTES MARCIALES'
#  'CUALQUIER LIGA DE LEAGUE OF LEGENDS' 'LEAGUE OF LEGENDS' 'LOL'
#  'LEC , ESL' 'COUNTER STRIKE' 'COMPETICONES CARRERAS COMPETITIVAS'
#  'LOL PROFESSIONAL, NACIONAL I INTERNACIONAL'
#  'ESPORTS DE LEAGUE OF LEGENDS' 'LIGA PLEGENTS' 'BRAZILIAN JIU JITSU'
#  'COMPETITIU DE LEAGUE OF LEGENDS' 'CLASS (LEAGUE OF LEGENG)'
#  'WORLDS DE LEAGUE OF LEGENDS' 'CARRERAS DE COCHES' 'FIFAÇ'
#  'LIGUE OF LEGENDS' 'BASQUET' 'LEC' 'AGE OF EMPIRES Y SUPER SMASH'
#  'ESPORTS' 'BÉISBOL' 'COUNTER-STRIKE GLOBAL OFFENSIVE, LEAGUE OF LEGENDS'
#  'COMPETICIONS DE LEAGUE OF LEGENDS' 'ARENACHAMPIONS' 'BALONCESTO'
#  'LEA SPORT, CALL DUTY, FIFA' 'LCS, LVP' 'ROKERLI, COMTER STRIKE'
#  'FULTBOL' 'ELALIGA' 'CLASH'
#  'WORLDS LEAGUE OF LEGENDS I LEAGUE OF LEGENDS EUROPEAN CHAMPIONSHIP'
#  '-CALL OF DUTI, START CAST' 'LVP'
#  'LIGA DE ONWARD DE EGAMESVR / LIGA DE BREACHERS DE EGAMESVR'
#  'FIFA FULL CHAMPIONS' 'FUTBOL,' 'EVO'
#  'FUTBOL, FORMULA 1, TENIS. MOTOCICLISMO. GOLF. AUTOMOVILISMO. BASQUET. BOLOS.'
#  'CONDUCION, FUTBOL' 'CICLISMO' 'F1'
#  'LIGA DE EQUIPO DE PAÍSES, CLANS OF CLANS' 'BALONMANO'
#  'DEPORTES DE MOTOR' "M'INTERESEN LES COMPETICIONS DE VALORANT"
#  'ATLETISMO, NATACIÓN, MUAYTHAI' 'FORNITE' 'UFC, ARTES MARCIALES' 'ESPORT'
#  'A LOS BOLOS' 'PREMIER LEAGUE, LLIGA ACB' 'FORTNITE (FNCS)' 'CHAMPIONS'
#  'CHAMPIONS LEAGUE, LA LIGA' 'LOL, VALORANT, APEX'
#  'SIMRACING SIMULACIO DE CONDUCCIO COMPETITIVA' 'CICLISME'
#  'RALLYS, CALL DUTY'
#  'LEC, SUPERLIGA, MUNDIAL DEL LOL, SUPERLIGA SEGUNDA, IBERIAN CUP'
#  'LION PLAYER' 'CARRERES DE COTXES' 'FORMULA 1' 'MOTOCICLISMO'
#  'OVERWATCH OPEN DIVISION' 'FUTBOL,CARRERAS' 'FNCS, FIFAE'
#  'LIGA DE LEYENDAS' 'APEX LEGENDS GLOBAL SERIES' 'MUNDIAL DEL LOL'
#  'BASQUET, MOTOR' 'CALL OFF DUTY' 'CLASH ROYALE' 'LEGO LEGENTS'
#  'CICLISME, ESPORTS DEL MOTOR' 'STRONGMAN, POWERLIFTING, BASKET' 'COTXES'
#  'CARRERAS,FUTBOL' 'KING BOXING' 'BALORAN' 'FOOTBALL' 'GWENT MASTERS'
#  'MUNDIALS DE VALORANT I LOL' 'LEAGUE OF LEGENT' 'SHOT GAMES'
#  'LEAGUE OF LEGENDS WORLD CHAMPIONSHIP' 'MUNDIALES' 'LIGA FLREGENT'
#  'LA LLIGA' 'LOS QUE SE REALIZAN EN CONVENCIONES' 'MARIO KART'
#  'UNA COMPETICIÓ DE VIDEOJOCS QUE ES REALITZAVA ANUALMENT A LA SEU D?URGELL ABANS DEL COVID'
#  'LEAGUE OF LEGENDS CHAMPIONSHIP SERIES NA Y EU'
#  'VALORANT WORLDS, LOL WORLDS' 'TAKEWONDO (ARTS MARCIALS)'
#  'CIRCUITO TORMENTA DE LEAGUE OF LEGENDS' '-BOXEO' 'ASSETTO CORSA'
#  'LLUITA' 'LIGUES LEGEND' 'TAEKWONDO']
#
#
# Valores únicos para la columna LL5A#value:
# ['0' 'INTERNET' 'PORTATIL' 'N/A' 'AUDIOLIBROS' 'AUTOBIOGRAFIA'
#  'PÁGINAS WEB SOBRE LECTURA (E.G. GOODREADS)' 'LEO MANGA, EL QUE ME GUSTA'
#  'CERCO PER INTERNET' 'FÒRUMS' 'PAGINA WEB' 'CERQUES ONLINE' 'YOU TUBE'
#  'ALGUN AUTOR HISTÓRICO QUE ME GUSTE Y SEPA QUE HA SACADO UN LIBRO'
#  'INTERNET EN GENERAL' 'BUSQUEDA WEB' 'POR LO QUE YO SE'
#  'INVESTIGO EL GÈNERE DE FANTASIA, CIENCIA FICCIÓ, BEST SELLERS .... A LA WEB I TRIO'
#  'TIENE MUCHOS EN CASA' 'INTERÈS PROPI' 'LLIBRES ESMENTATS A LLIBRES'
#  'INTERNET INFORMACIÓ' 'LLEGIR CRÍTIQUES' 'ACTORES'
#  'POR REFERENCIAS PERSONALES' "PQ CONEIX L' AUTOR" 'SEGÚN EL AUTOR'
#  'AMAZON' 'POR CASUALIDAD'
#  'RECOMEDACIONES DE LAS APPS BASADAS EN LOS LIBROS QUE LEO'
#  'PORQUE HA VISTO LA PELICULA' 'DE LA SEVA UNIVESITAT VIA WEB'
#  'REVIEWS INTERNET' 'UN TEMA ESPECÍFIC QUE VULL CONÈIXER' 'IINTERNET'
#  'PODCASTS' 'SINOPSIS EN INTERNET' 'POR INTERNET' 'FERIAS DE LIBROS'
#  'POR AUTOR' 'POR TU CUENTA' 'APLICACION POR INTERNET'
#  'PERQUE LI AGRADA ÑL´AUTOR' 'EN FUNCIÓN DE LA TEMÁTICA'
#  'AUTORES Y RECOMENDACIONES AMAZON' 'NOVELA ROMANTICA Y DE SUSPENSE'
#  'TINC AUTORS PREFERITS.' 'APLICACION    WATAP'
#  'ENTREVISTAS DEL AUTOR DEL LIBRO, SABER DE QUE VA EL LIBRO, CRITICAS Y OPINIONES  DEL LIBRO'
#  'MISTERIO , TIPO AGATHA CRISTIE' 'REVISTES DE LA ONCE'
#  'PER INTERÈS PERSONAL PUNTUAL' 'TIENE MUCHOS LIBROS EN CASA'
#  'ME LOS TRAE MI HIJA' 'FAMILIA' 'JO MATEIXA' 'CLUB DE LECTURA'
#  'POR ESCRITOR' 'EL QUE LE APETECE QUE TENGO EN CASA' 'REVISTAS'
#  'PER INTERNET' "OBLIGACIÓ D'ASSIGNATURES DE CATALÀ I CASTELLÀ"
#  'RECERCA PER INTERNET' "EL QUE M'INTERESSI AL MOMENT"
#  'MERCADILLO DE SEGON MA'
#  'LLEGEIXO HABITUALMENT EN ANGLÈS I BUSCO PER INTERNET AQUELLS QUE NO TINGUIN UN NIVELL MOLT EXIGENT, PER EXEMPLE  QUE HAGIS DE TENIR UN NIVELL AVANÇAT EN LA LLENGUA SINÓ QUE TRIARÉ UN DE NIVELL INTERMEDI.'
#  'TIENE EN CASA' 'PREMIS LITERARIS'
#  'CONOZCO LOS ESCRITORES,CONOCE LOS AUTORES' 'INTERÉS PROPIO'
#  'ME LO REGALAN' 'ME INFORMO POR MI PROPIA CUENTA' 'YOUTUBE'
#  'PAGINAS WEBS EN PC' 'REVISTES QUE INCLOUEN RESSENYES DE LLIBRES'
#  'AMAZON PRIME' 'FAMILIARES' 'CURIOSITAT' 'AMAZON - AUDIBLE' 'PROPIA'
#  'EL MEU CRITERI' 'CONEIXER EL LLIBRE'
#  'BUSCO OPCIONES Y LEO RESEÑAS ANTES DE ELEGIR' '-BIBLIA'
#  'BIOGRAFIA E HISTOIA' 'PÁGINAS WEB'
#  'RECOMANACIONS TROBADES A WEBS ESPECIALITZADES'
#  'DEPENT DEL QUE ESTIC FENT' 'SI LI DEIXEN EL LLIBRE'
#  'RECOMENDACIONES DE ARTISTAS' 'INTERNET (DE PROMOCION)'
#  'EL SEU MATEIX CRITERI' 'EXPERIENCIA' 'PAGINA WEB: GOOD READ'
#  'QUE APAREZCA EN MI VIDA DE UNA U OTRA FORMA']
#
#
# Valores únicos para la columna AS2#value:
# ['0' 'ESPLAI' 'ULTRAS' 'N/A' "MONITOR D'ESPLAII" 'ECONOMICO   REVISTA'
#  'BASTONAIRE' 'LITERATURA' 'MUNTANYA' "COL·LECTIU D'ARTISTES" 'FUTBOL'
#  'EXCURSIONISME' 'JOCS DE SIMULACIÓ I ESTRATÈGIA' 'IGLESIA PENTECOSTES'
#  'AYUDAS PARA EL AUTISMO' 'ESCACS' 'DERECHOS LGTBI' 'DEPORTE'
#  'ASOCIACIÓN CULTURAL GNÓSTICA' 'ASSOCIACIÓ DE VEÏNS' 'RELIGIOSO'
#  'PROFESSIONAL' 'AJEDREZ' 'PETANCA' 'POLÍTICA' 'REPOBLAMENT'
#  'ESPAI JOVE BOCA NORD, ACTIVISTAS VARIAS' 'ASSOCIACIO JOVE CULTURAL'
#  'JOVENTUT' 'CATOLICISMO' 'BARCELONA CUIDA' 'CIÈNCIA' 'JOCS DE TAULA'
#  'AVIACION' 'GENERO IDENTIDAD SEXUAL' 'GRUPO EXURSIONISA' 'CASA REGIONAL'
#  'ACITIVIDADES SALIDAS' 'CLUB LECTURA' 'PINTURA' 'SARDANA' 'MUSICAL'
#  'PROTECTORA ANIMALES' 'VECINOS' 'MUSEOS' 'AFECTADOS POR LA FIBROMIALGIA'
#  'CASAL DEL POBLE' 'CENTRO CULTURAL EUROPEO, VIAJES, SALIDAS, SENDERISMO'
#  'CASAL GENT GRAN' 'PLATAFORMA GENT GRAN' 'GRUP SKATERS' 'ROL'
#  'CULTURAL, SOCIAL I RELIGIOSA' 'BIOTECNOLOGIA' 'GARANTIA JUVENIL'
#  'AJUDA DISCAPACITATDS' 'BIBLIOTECA' 'DE MUNTANYA' 'AMBIT RURAL'
#  'GENT GRAN' 'CRISTIANA' 'ASOCIACIÓN DE VECINOS' 'LGTB'
#  'CLUB DE LA JUVENTUD' 'ASSOCIACIO DE DONES' 'CREU ROJA' 'CLUB DE LECTURA'
#  'EXCURSIONISTA' 'ASSOCIACIÓ DE JOVES' 'SENDERISME' 'JOCS TRADICIONALS'
#  'BIBLIOTECONOMIA' 'CAU' 'RELIGIOSA' 'PREMSA LOCAL' 'GERIATRIC'
#  'FESTA MAJOR I FESTIUS' 'DONES' 'DONES I JUBILATS' 'OCI I CULTURA'
#  'MUJERES' 'JUVENIL' 'CULTURA POPULAR' 'BALONCESTO' 'ESPLAI D?OCI']
#
#
# Valores únicos para la columna LN1#value:
# ['0' 'N/A' 'GUARANI' 'ARA' 'RUSO' 'ARABE' 'ARABE/CASTELLANO/CATALÁN'
#  'MARROQUÍ' 'URDU' 'ITALIANO'
#  'SONINKE, IDIOMA AFRICANO ,EN SENEGAL Y MALI' 'RUS' 'CHINO' 'XINÈS'
#  'GUARANÍ' 'SENEGAL' 'JAPONES, Y CASTELLA' 'PORTUGUÉS' 'BANGLA' 'MARROQUI'
#  'ÀRAB' 'XINÉS' 'EGIPCI' 'PERSA' 'BERÉBER' 'ARBAE' 'BÚLGAR' 'FILIPINO'
#  'GUARENI' 'GALLEGO' 'ARABIC' 'ROMANES' 'HOLANDES' 'ÁRABE' 'BEREBER'
#  'CHINA' 'TANGI' 'VASC' 'MANDINGA' 'MONGOL' 'UCRANIANO' 'TVBI' 'TVI'
#  'EUSKERA' 'HOLLANDES' 'PUNJABI' 'ÂRAB' 'GUALOK' 'XINO' 'ARMENIO'
#  'TAGALOG' 'SONINKE/SARANGULE' 'DARI' 'TAMAZIGHT'
#  'RISEÑO../8DIALECTO DE MARROQUI' 'WOLOF' 'PORTUGUÊS' 'VALENCIA' 'RUMANO'
#  'PORTUGUES' 'ORIYA' 'CHI?NO' 'CADAKISTAN' 'CHECO' 'LLENGUA DE SIGNES'
#  'ITALIÀ' 'BÚLGARO' 'TURCO' 'TWI' 'MAMOLE, FALA Y SILBO GOMERO' 'VALENCIÁ'
#  'SUECO' 'UCRAINÈS' 'INDIO' 'ARAB' 'GAMBIANO (SORINKE)' 'SONINKE'
#  'PENJAVI' 'FULA' 'YAJANLKO' 'BELVER' 'INDIA' 'RUMANES.' 'AMAZIGH'
#  'GALEGO' 'RUMANMO' 'VIZAIA' 'ROMANIA' 'BERBER' 'AMASÍ' 'AMAZIC'
#  'PORTUGUES DEL BRASIL' 'ARBI' 'KAMBA' 'CHAPURREAU' 'CHINES' 'ROMANÉS'
#  'GHANAIAN LANGUAGE' 'ARGELINO' 'BEREVE' 'DARIJA' 'UCRANIA'
#  'ESFULA (AFRICANA)' 'ROMANÈS' 'BULGARO' 'ARANES' 'GALLEC' 'BENGALI'
#  'HOLANDÉS' 'TANT CATALA COM CASTELLA' 'POLONÉS' 'RIFEÑO']
#
#
# Valores únicos para la columna LN2#value:
# ['0' 'FILIPINO' 'GUARANI' 'N/A' 'ARABES' 'RUSO' 'UCRANIANO' 'ARABE'
#  'SUISS ALEMANY' 'GEORGIANO' 'MARROQUÍ' 'SONINKE,' 'RUS' 'CHINO'
#  'MARROQUI' 'RUMANO' 'XINÈS' 'SENEGALES' 'DIOLA' 'JAPONES' 'PORTUGUÉS'
#  'BANGLA'
#  'HABLAMOS EN ESPAÑOL, DEJEN DE BUSCAR EXCUSAS Y GASTAR DINERO PUBLICO PARA OBLIGAR A LA GENTE A HABLAR UNA LENGUA QUE NO CONOCEN. HAY MULTITUD DE INMIGRANTES QUE DESCONOCEN LA LENGUA. RESPETEN A ESA GENTE.'
#  'URDU' 'ÀRAB' 'ITALIÀ' 'XINÉS' 'EGIPCI' 'PERSA' 'ARABE, BEREBER'
#  'BERÉBER' '-ARMENIO' 'BÚLGAR' 'URDU Y INGLES' 'EUSKERA' 'ARABE Y GARIJA'
#  'CHINO DIALECTO' 'ARABIC' 'ROMANES' 'HOLANDES' 'ÁRABE' 'GALLEGO'
#  'ITALIANO' 'BEREBER' 'CHINA' '-URDU' 'MANDINGA' 'MONGOL' 'FLAMENC'
#  'VALENCIANO' 'TVI' 'BÚLGARO' 'GREC' 'SOMOS MAYORES..ESPAÑOL.' 'TAGALOG'
#  'ILOCANO' 'PUNJABI' 'RUMANES' 'ÂRAB' 'ITALIA' 'ARAB' 'XINO' 'ARMENIO'
#  'ÁRAB' 'SONINKE/SARANGULE' 'XINES' 'TAMAZIGHT' 'URDÚ, PUNJABI'
#  'ITALIÀ, PORTUGUES' 'WOLOF' 'GALLEC' 'GUARANÍ' 'PORTUGUÊS' 'VALENCIA'
#  'CADA' '-MADECO' 'TURCO' '-ARABE' 'VALENCIÁ' 'SUECO' 'UCRAINÈS' 'INDIO'
#  'AMAZIC' 'TWI' 'SORINKE' 'SONINKE' 'INDI' 'ARABE BEREBER' 'FULA'
#  'ARABE IAMAZEH' 'YAJANKO' 'ARABE, BELVER' 'BABLE, GALLEGO'
#  'MANDINCA(SENEGAL)' 'INDIA' 'SARANHULE' 'AMAZIGH' 'ROMANIA' 'FANTE'
#  'ARABE,BEREBER' 'RUAMNO' 'RIFEÑO' 'TAGALOG E ILOCANO' 'ARABI'
#  'CHAPURREAU' 'ARANES' 'CHINES' 'ROMANÉS' '-BERBER' 'AMASÍ' 'TRIOL'
#  'GHANAIAN LANGUAGE' '-GUARANI' 'ARGELINO' 'ÁRABES' 'BEREBE' 'DARIJA'
#  'UCRANIA' '-FULA' 'EUSKAR' 'AFRICANA' 'POLACO' 'PORTUGUES' 'BULGARO'
#  'BENGALI' 'HOLANDÉS' 'CHECO' 'POLONÉS' 'ARABE/AMAZIC']
#
#
# Valores únicos para la columna LN3#value:
# ['0' 'N/A' 'ARABES' 'ARABE' '-ARABE/CASTELLANO' 'SONINKE,' 'ITALIANO'
#  'CHINO' 'SENEGALES' 'XINÉS' 'ÁRABE' 'ARMENIO' 'URDU' 'GARIJA' 'ROMANES'
#  'HOLANDES' 'BEREBER' 'ARAB' 'MONGOL' 'BEREBERE' 'UCRAUNIO' 'RUSO'
#  'GALLEGO' 'GUARANI' 'GUALOK' 'DARI' 'TAMAZIGHT' 'TAGALOG' 'WOLOF' 'ÀRAB'
#  'PORTUGUÊS' 'VALENCIA' 'UCRANIANO' 'BÚLGARO' 'BULGARO' 'TWI' 'SUECO'
#  'SORINKE' 'PENJAVI' 'FULA' 'YAJANLO' 'AMAZIGH' 'RUMANO' 'ROMANIA' 'FANTE'
#  '-AMAZIC' 'ARABE ESPAÑOL' 'ARABIC' '-EOLOF' 'PORTUGUES' 'CHINES'
#  'MARROQUINA' 'BERÉBER' 'ARGELINO' 'AMAZIC' 'BEREBE' 'BÚLGAR' 'UCRANIA'
#  'AFRICANA' 'ARANES' 'RIFEÑO']
#
#
# Valores únicos para la columna LN4#value:
# ['0' 'N/A' 'UCRANIANO' 'ARABE' '-ARABE' 'SONINKE,' 'ITALIANO' 'CHINO'
#  'XINÈS' 'SENEGALES' 'BANGLA' 'XINÉS' 'EGIPCI' 'PERSA' 'ÁRABE' 'ARMENIO'
#  'URDU' 'FILIPINO' 'GARIJA' 'ARABICA' 'RUS' 'ROMANES' 'HOLANDES' 'GALLEGO'
#  'BEREBER' 'CHINA' 'MANDARIN' 'MANDINGA' 'MONGOL' 'RUSO' 'TVBI' 'TVI'
#  '-URDU' 'EUSKERA' 'HOLLANDES' 'GUALOK' 'ÁRAB' 'SONINKE/SARANGULE' 'DARI'
#  'TAGALOG' 'WOLOF' 'ÀRAB' 'GUARANÍ' 'PORTUGUÊS' 'VALENCIA'
#  '-ARABE/ESPAÑOL' 'PORTUGUÉS' 'MANDECO' 'CHECO' 'BULGARO' 'TWI' 'VALENCIÁ'
#  'SUECO' 'UCRAINÈS' 'SORINKE' 'SONINKE' 'PENJVI' 'FULA' 'YAJANKO' 'BELVER'
#  'BINI' 'INDIA' 'SARANHULE' 'RUMANES' 'AMAZIGH' 'RUMANO' 'SONIKE' 'GALEGO'
#  'VIZAIA' 'ROMANIA' 'BERBER' 'AMAZIC' '-PORTUGUES DEL BRASIL' 'ARAB'
#  'KAMBA' 'AREBE' 'CHINES' 'MARROQWUINA' '-ÁRABE' 'HINDI PUNJABI'
#  'GHANAIAN LANGUAGE' '-CASTELLANO/GUARANI' 'ARGELINO' 'BEREVE' 'BÚLGAR'
#  'PUNJABI' 'DARIJA' 'UCRANIA' 'FULA (AFRICANA)'
#  'VARÍA SEGÚN EL MOMENTO (ENG Y ESP)' 'PORTUGUES' 'ARANES' 'BENGALI'
#  'ÁRABE,CASTELLANO' 'RIFEÑO']
#
#
# Valores únicos para la columna LN7#value:
# ['0' 'FRANCÉS' 'FRANCÈS' 'FILIPINO' 'GUARANI' 'ALEMANY' 'ARAB' 'RUSO'
#  'ALEMAN Y FRANCES' '-UCRANIANO' 'ARABE, FRANCES'
#  'SUISS-ALEMANY, ALEMANY, FRANCÉS' 'ARABE'
#  'ENTIENDO FRANCÉS E ITALIANO PERO NO LOS HABLÓ NI LOS ESCRIBO'
#  'GEORGIANO' 'PORTUGUÊS' 'SUEC' 'MARROQUÍ' 'ANGLÈS' 'ALEMÁN'
#  'FRANCÉS UNA MICA' 'N/A' 'URDU' 'ITALIÀ' 'INGLÉS' 'ITALIANO' 'JAPONES'
#  'ALEMAN UN POCO' 'SINKELE' 'RUS' 'CHINO' 'FRANCÈS, ITALIÀ' 'MARROQUI'
#  '-ALEMANY' 'JAPONÉS' 'FRANCES' 'ENTIENDO Y SE HABLAR RUMANO' 'XINESA'
#  'ALEMANY, JAPONÉS' 'SENEGALES, FRANCES' 'DIOLA' 'PORTUGUES' 'GALLEGO'
#  'BANGLA, HINDI, URDU' 'MARROQUI, FRANCES' 'ALEMAN'
#  'INGLÉS FRANCÉS  Y PORTUGUÉS' 'ÀRAB' 'XINÉS' 'EGIPCI' 'FRANCES, LATIN'
#  'FRANCES, ARABE, BEREBER' 'ITALIANO O PORTUGUES' 'ÁRABE, BERÉBER'
#  'ÁRABE Y FRANCÉS' 'FRANCES, PORTUGUES' 'ITALIA,' 'INGLES' 'BÚLGAR'
#  'ÁRABE' 'JAPONÈS' 'URDU HINDI' 'EUSKERA' 'ARABE Y BEREBER'
#  'PORTUGUES Y GUARANJ' 'ITLAQIA' 'GALLEC'
#  'PORTUIGUES, ITALIANO, GALLEGO, FRANCES' 'ITALIA' 'ALEMÁN, ITALIANO'
#  'ROMANES' 'PORTUGUÉS,  FRANCÉS, ITALIANO' 'HOLANDES, FRANCES, ALEMAN'
#  'ALEMANY, ITALIÀ' 'ITALIANO, FRANCÉS' 'PORTUGUÉS' 'VALENCIANO'
#  'ÀRAB I AMAZIC' 'FRANCES......' 'CHINA' 'ANGLES' 'MANDARIN,' '-PORTUGUÈS'
#  'MANDINGA' 'MONGOL' 'BEREBER , ARABE' 'FRANCÉS I ITALIÀ'
#  "FRANCÈS, ITÀLIA, NOCIONS D'ALEMANY" 'FRANCÉS, EUSKERA' 'UCRANIANO'
#  'FLAMENC, ALEMANY, FRANCÈS' 'TWI' 'TVI' 'GALLÈC' 'ALEMÁN, BÚLGARO'
#  'FRANCES, RUSO, RUMANES' 'ALGO DE FRANCÉS (NIVEL BAJO - MEDIO).' 'GREC'
#  'PORTUGUES ITALIANO FRANCES' 'GUARANÍ' 'HEBREO' 'ALEMNAY' '-ITALIANO'
#  'PORTUGUES E ITALIANO' 'HOLLANDES, ALLEMAN' 'ITALIÁ, FRANÇES' "'FRANCES"
#  'ITALIA I FRANCES' 'ITALIANO Y FRANCES' 'FRANCES, ITALIANO'
#  'FRANCES, ITALIA, ROMANES' 'FRANCES , ITALIANO , GALLEGO'
#  'FRANCES, ITALIA' 'FRANCES ITALIA' 'ITALIANO. LO HABLO.' '-FRANCÉS'
#  'ANGLÉS' 'LLATI' 'UN POCO FRANCÉS' 'AYMARA' 'FRANCÉS, ITALIÀ' 'FRANDES'
#  'FRANCES, ALEMAN, GRIEGO' 'TAGALOG' 'MEDIO JAPONÉS' 'PORTUGUÉS, FRANCÉS'
#  'EL FRANCÈS, ALGUNES COSES' 'ILOCANO Y TAGALOG' 'ALEMANY I XINÈS' 'FULA'
#  'PUNJABI' 'GREC I LLATÍ' 'FRANÇAIS PERÒ NO MOLT' 'RUMANES' 'ÂRAB'
#  'GUALOK DE SENEGAL' 'FRANCÈS, PERÒ AMB DIFICULTATS' 'FRANCÈS,ITALIÀ'
#  'FRANCÉS, ITALIANO' 'ÁRABE -'
#  "VAIG A CLASSES D'ALEMANY PER ASSIGNATURA OPTATIVA A L'INSTITUT"
#  'FRANCÈS, ITALIÀ.' 'XINO' 'ARMENIO' 'ÁRAB' 'FRANCÉS I EL VALENCIÀ'
#  'COREANO' 'LITUANO' 'SONINKE/SARANGULE' 'DARI,PASHTO,'
#  'FRANCÈS I NEERLANDÈS'
#  'ENTIENDO UN POCO DE FRANCÉS, LO PUEDO ESCRIBIR Y HABLAR CON UN POCO DE DIFICULTAD'
#  'JAPONÉS (CON DIFICULTADES)' 'XINÈS' 'BOLIVIA' 'NEERLANDÈS'
#  'ITALIÀ ALEMANY' 'FRANCES.' 'PORTUGUÉS (ENTENDRE NOMÉS)'
#  'URDU, PUNJABI, HINDI' 'ARABE, FRANCES, TURCO' 'PORTUGUÈS'
#  'ITALIANO, RUSO' 'RISEÑO  (ES UN DIALECTO MARROQUI)' 'ÁNGLES'
#  'FRANCÉS, ALEMAN, WOLOF' 'ALEMÁN, UN POCO DE CHINO' 'FRASNCES'
#  'FRANCES I ITALINAO' 'ALEMÁN Y CHINO CON ALGUNAS DIFICULTADES' '-TAGALO'
#  'ÀRAB, TAMAZIGHT, MARROQUÍ' 'FRAMCES' 'XINES' 'ITALIÀ I FRANCÈS'
#  'SÉ UN POCO DE FRANCÉS' 'ALEMANY,FRANCÈS' 'ALEMANY, FRANCÈS'
#  'FRANCÈS, COREÀ' 'PORTUGUES BRASILEÑO' 'FRANCES  E ITALIA' 'ALEMANYÇ'
#  'FRANCÉS, MI IDIOMA NATIVO' 'ITALIANO, FRANCES' 'VALENCIA'
#  'FRANCES Y RUMANO' '-ALEMANY I FRANCÈS A NIVELL BÀSIC' 'POCO URDU'
#  'ITALIANO, PORTUGUÉS' 'ALEMANY, ITALÀ' 'RUMANO'
#  "FRANCÈS, PERÒ AMB MÉS DIFICULTATS QUE L'ANGLÈS, QUE TAMBÉ EN TINC DE DIFICULTATS AMB L'ANGLÈS"
#  'ALEMAN, FRANCÉS' 'FRANCÉS, ALEMÁN,PORTUGUÉS'
#  'PUNJABI(LENGUA DE PAKISTAN)' 'BEREBER' 'CHECO, ESLOVACO, RUSO'
#  'FRANCES    ITALIA' 'FRANCÈS, ALEMANY' 'ITALIANO, ALEMAN'
#  'POLACO, UCRANIANO, RUSO' 'GALLEC I FRANCÉS' 'FRANCÈS / ALEMANY'
#  'ITALIÀ, ALEMANY, FRANCÈS, PORTUGUÈS' 'BÚLGARO,RUSO' 'EL GUARANÍ'
#  'FRANCES, GALLEGO, PORTUGUES'
#  "FRANCÈS (PARLAT I ESCRIT). ENTENC I PARLO ITALIÀ (NO L'ESCRIC). ENTENC PORTUGUÈS."
#  'FRANCÈS, BRASILER, ITALIÀ' 'BULGARO' 'RUSO ALEMAN  ITALIANO FRANCES'
#  'ENTENC ITALIÀ' 'ARMENIO,RUSO,INGLES' 'FRENCES Y ARABE' 'ALEMAN FRANCES'
#  'FRANCÉS, ITALIÀ, POTUGUÉS' 'ALEMANY, FRANCÈS I PORTUGUÈS'
#  'UCRANIANO , RUSO , ALEMAN' 'ITALIANO, GALLEGO' 'ARABE, BEREBER'
#  'ITALIANO . FRANCES' 'SUECO' 'FRANCÉS/ÁRABE'
#  'FRANCES, ITALIA I PORTUGUES' '-FRANCÈS' 'UCRANIAMO'
#  'ITALIANO Y FRANCÉS NIVEL MEDIO' '-FRANCES' 'ALGO DE FRANÇES' 'EXTREMEÑO'
#  'UCRAINÈS, RUS' 'INDIO' 'FRANCES PARLAR UNA MICA' 'AMAZIC' 'HOLANDES'
#  'MANDINGA,WOLOF,' 'SORINGUE' 'SONINKE' 'FRANCES - RUMANO' 'FRANCES,'
#  'FRANCES Y RUS' 'ITALIA FRANCES' 'JUVI' 'FRANCÈS, ITALIÀ I PORTUGUÉS'
#  'FULA, FRANCES, UOLOF (SENEGAL)' 'FRANCES E ITALIANO' 'YAJANKO' 'BELVER'
#  'FRANCÈS I ITALIÀ' 'BABLE, GALLEGO' 'FRANCÉS-' 'MANDINCA' 'INDIA'
#  'ÀRAB, FRANCÈS' 'FRANCÈS I ALEMANY' 'FRANCÈS, ARABE, AMAZIGH'
#  "L'ÀRAB I EL FRANCÈS" 'SONIKE' 'GALEGO' '-ARABE' 'ARABRE, BEREBER'
#  'VIZAIA' 'ROMANIA' 'ALEMANY, FRANCES (EL FRANCES LI COSTARIA ESCRIUREL)'
#  'FANTE' 'BEREBER, FRANCÉS, ÁRABE' 'PORTUGUES I ITALIÀ' 'AMASI, ARAB'
#  'FRANCES LENGUA MATERNA' 'FRANCÉS/ALEMANY' 'FARABE'
#  'PARLO FRANCSES I BAMBARA' 'FRA NCÉS' 'PORTUGUES DEL BRASIL' 'RIFEÑO'
#  'ARAB, FRANCES' 'ARAB, NOMÉS PARLAR' 'ALEMÀ' 'INGLÉS Y FRANCÉS'
#  'FRANCES Y NÉERLANDAIS' 'FRANCÈS I PORTUGUÈS (AMBDUES NIVELL BAIX/MIG)'
#  'ARABI' 'KISWAHILI Y KAMBA' 'WOLOF' 'FRANCÉS I RUS'
#  'FRANCES, EUSKERA, RUSO' 'ARANERS' 'ROMANÉS'
#  'FRANCES (LO ENTIENDE, LO HABLA Y LO ESCRIBE), ALEMAN (LO ENTIENDE Y LO HABLA)'
#  'AMASÍ, ARABE' 'CRIOL' 'GHANAIAN LANGUAGE' 'ALEMANYA, FRANCÈS I ITALIÀ'
#  'ARGELINO' 'ÁRABES FRANCÉS' 'FRANCES I BEREBER'
#  'JAPONÉS, FRANCÉS, ALEMÁN, PORTUGUÉS' 'EL FRANCÈS, PERO AMB DIFICULTATS.'
#  '-AMAZIC' "EM DEFENSO PERÒ EM MANCA FORÇA CONEIXEMENT DE L'ANGLÈS"
#  'FRANÇAIS' 'ARAB I FRAÇES' 'FULA (AFRICANA)' 'ÁRABE, SOL PARLAR'
#  'UNA MICA DE FRANCÈS' 'ROMANÈS' 'RUMANO, ALEMAN' 'ARANES'
#  'ARANÉS Y FRANCÉS' 'FRANCÉS I GALLEC' 'BENGALI'
#  'ENTIENDO ITALIANO BÁSICO' 'GALLEGO, ITALIANO Y FRANCÉS'
#  'ARAB, BEREBER, FRANCES' 'HOLANDÉS' 'ITÀLIA' 'ÁRABE, FRANCÉS' 'CHECO'
#  'FRANCES, CASTELLA' 'POLONÉS' 'ALEMÁN, ITALIANO Y FRANCÉS'
#  'AMAZIC/ ARABE' 'ÁRABE SOLO HABLAR' 'RUSO, UCRANIANO Y CHINO']
#
#
# Valores únicos para la columna OR2#value:
# ['0' 'VENEZUELA' 'AITI' 'PERÚ' 'ECUADOR' 'MARROUECOS' 'CIUDAD MEJICO'
#  'MARRUECOS' 'CASTILLA Y LEÓN' 'MARROC' 'UCRANIA' 'REIDO UNIDO' 'PAKISTÁN'
#  'COLOMBIA' '-JAPÓ' 'GAMBIA' 'ARGENTINA' 'HONDURAS' 'SENEGAL' 'CHINA'
#  '-BRASIL' '-MARRUECOS' 'PERU' 'BOLIVIA' 'PAKISTAN' 'RUSIA' 'EGIPTE'
#  'PERSIA' 'NICARAGUA' 'BULGÀRIA' 'ALEMANIA' 'ARABE' 'FRANÇA' 'BÉLGICA'
#  'ESPAÑA' 'MAROC' 'URUGUAY' 'ARMENIA' 'REPUBLICA DOMINICANA' 'BULGARIA'
#  'CUBA' 'BOGOTA' 'REPÚBLICA DOMINICANA' 'COLÒMBIA' 'FILIPINAS' 'PARAGUAY'
#  '-IRAN' '-HHONDURAS' 'RÚSSIA' 'ALEMANYA' 'PAISES BAJOS' 'ITALIA' 'MALI'
#  '-ITALIA' 'MEXICO' 'EL SALVADOR' 'EL MARROC' 'MALTA' 'CHINA HAN'
#  'PORTUGAL' 'ADOR (MARRUECOS)' 'FRANCIA' 'CHILE' '-UCRANIA' 'BARCELONA'
#  'RUSO' 'GHANA' 'GANA' 'MONDAVIA' 'CIKE' 'SALVADOR' 'ALEMNYA' 'HOLLANDA'
#  'LONDRES' 'BRASIL' 'TETUAN' 'VENEÇUELA' 'XILE' 'ESTATS UNITS' 'SUIZA'
#  'SIRIA' 'MALLORCA' 'INDIA' 'XINA' '-FRANÇA' 'AFGANISTAN' 'PANAMÀ'
#  'EQUADOR' 'LIBANO' 'TANGER' 'MÈXIC' 'HONDUR' 'HONDURAS3' 'SALVADOER'
#  'BELARUS' 'MEJICO' 'GEORGIA-RUSIA' 'RUMANIA' 'ESPAÑOL' 'CHINO' 'RUMANÍA'
#  '-URUGUAY' 'CARACAS, VENEZUELA' 'PAQUISTAN' 'CADAKISTAN' 'ESPANOL'
#  'CHEQUIA' '-CUBA' '-SANTO DOMINGO' 'ITÀLIA' 'CASTELLANO' 'RUSA'
#  'COSTA RICA' 'SUISSA' 'INGLATERRA' 'MOLDAVIA' 'URUGUAI' 'GANA, AFRICA'
#  'AUSTRIA' 'MURCIA' 'PERUANA' 'SUECIA' 'PAMPLONA' 'TUNEZ' 'CIUDAD REAL'
#  'ESCOCIA' 'BARCELONA ESPAÑA' 'SANTIAGO DE CHILE' 'POLRTUGAL'
#  'REPUBLICA DOMENICANA' 'RUMAIA' 'ROMANIA' 'TARRAGONA' 'GUATEMALA'
#  '-COLOMBIA' 'MARROQUI' '-PUERTO RICO' 'XINA (ADOPCIÓ)' 'FRANCÉS'
#  'DOMINICANA' 'MACHAKOS-KENIA' '-MARROC' 'HOLANDA' 'MARERUECOS' 'ETIÒPIA'
#  'ARGELIA' 'NIGERIA' 'AMRITSAR' 'EGIPTO' 'ALGERIA' 'ANDORRA' 'BANGLADESH'
#  'SANTO DOMINGO' 'POLÒNIA' '-ARGENTINA']
#
#
# Valores únicos para la columna G5#value:
# ['0' 'VENEZOLANA' 'PERUANA' 'PERUANA E ITALIANO' 'MARROUECOS' 'MEJICANA'
#  'MARROQUÍ' 'UCRANIANA' 'N/A' 'ITALIANA' 'COLOMBIANA' 'GAMBIANA' 'CHINA'
#  'ECUATORIANA' 'CHINO' 'PERÚ' 'RUMANA' 'XINÈS' 'HONDUREÑA' 'SENEGAL'
#  'ARGENTINA' 'VENEZUELA' 'BANGLADESH' 'MARROQUI' 'PAKISTAN' 'RUSA' 'XINÉS'
#  'EGIPTE' 'PERSIA' 'NICARAGUENSE' 'ARGELINA' 'FRANCESA' 'ARMENIA'
#  'BÚLGARA' 'COLOMBIA' 'PAKISTANI' 'ALEMANYA' 'FILIPINA' 'PARAGUAY' 'IRANI'
#  '-HHONDUREÑA' 'NICARAGUA' 'HOLANDES' 'PAISES BAJOS'
#  'ARGENTINO / ITALIANO' 'ITALIA' 'MALI' 'PARAGUAYA' 'MEXICANA' 'BRITANICA'
#  'EL SALVADOR' 'MOROC' 'CNINA' 'PORTUGUESA' 'BOLIVIANO' 'PERUANO'
#  'CHILENA' 'ALEMANA' 'REGNE UNIT' 'GHANA' 'SALVDOR' 'URUGUAYA'
#  '-VENEZOLANA I COLOMBIANA' 'HOLLANDES' 'FRANCES' 'PARAGUAYO'
#  'GRIEGA E INGLESA' 'MARROQUINA' 'XINA' 'ITALIANA Y VENEZOLANA' 'XINESA'
#  'PANAMENYA' 'PAKISTANÍ' 'SENEGALESA' '-HONDURE?A' 'BOLIVIA' 'COLOMBIANO'
#  'CUBA' 'ITALOARGENTINA' 'HONDURAS' 'SALVADOR' 'BELARUSIAN' 'ECUADOR'
#  'INDU' 'ARGENTINA, ITALIANA' 'MARROQWUI' 'BRASILEÑA' 'GEORGIANA' 'ALEMAN'
#  'MARRUECOS' 'ARGENTINA ITALIANA' 'SALVADOREÑA' 'INGLESA' 'CADAKISTAN'
#  '-MARROQUI' 'GUINEA' 'CHECA' 'UCRANIA' 'BOLIVIANA' 'DOMINICANA'
#  'COSTARRICENSE' 'SUIZA' 'BULGARA' 'ITALIANO'
#  'URUGUAYA,BRASILEÑA Y ESPAÑOLA' 'GANESA' 'AUSTRIACA' 'PERU' 'SUECA'
#  'TUNEZ' 'UCRAÏNESA' 'RESIDENCIA' 'GAMBIA' 'GANDIA' 'INDIA' 'RUMANESSA'
#  'REPUBLICA DOMINICANA' 'ALEMANIA' 'RUMANIA' 'MARROQUÍNA' 'ROMANIA'
#  'FRANCÉS' 'MARROC' 'GTM' 'XILENA' 'BRASILEÑO' 'PUERTO RICO I BRASILEÑA'
#  'HOMDUREÑA' 'MAROQUI' 'VENEZOLANA.COLOMBIANA.ESPANYOLA' 'ROMANESA'
#  'ARGELINO' 'MAROC' 'ECUATORIANO' 'NIGERIAN' 'ARGELIA' 'EGIPCIA'
#  '-COLOMBIA' 'POLACA' 'BULGARIA' 'DOMINICANA Y JAPONESA' 'BENGALI'
#  'HOLANDÉS' 'BELGA' 'VENEÇOLANA' 'POLONESA' 'AMERICANA' 'CUBANA'
#  'MARRROQUIÇ' 'ITA']
#
#
# Valores únicos para la columna OR4#value:
# ['0' 'FILIPINAS' 'VENEZUELA' 'PERU' 'PARAGUAY' 'ECUADOR' 'PERÚ'
#  'ARGENTINA' '-ECUADOR' 'MARROUECOS' 'CIUDAD MEJICO' 'MARRUECOS'
#  'COLOMBIA' 'GEORGIA' '-SUECIA' 'MARROC' 'UCRANIA' 'INGLES' 'ITÀLIA'
#  'ITALIA' 'GAMBIA' 'URUGUAY' 'CHINA' 'BOLIVIA' '-MARROQUI' 'RUMANIA'
#  'ESCOCIA' 'XINA' 'TANJER' 'FRANCIA' 'CAMERON' 'HONDURAS' 'SENEGAL'
#  'NIGERIA' '-BRASIL' 'ALEMANYA' 'BANGLADESH' 'PAKISTAN' 'RUSIA' 'ALEMANIA'
#  'EGIPTE' 'PERSIA' 'DINAMARCA' 'NICARAGUA' 'LIBANO' 'GUINEA BISSAÚ'
#  '-COLOMBIA' 'ARGELIA' 'FRANÇA' 'SIRIA' 'ESPAÑA' 'MAROC' 'PAKISTÁN'
#  'CHILE' 'INDIA' 'ARMENIA' 'REPUBLICA DOMINICANA' 'BULGARIA' 'CUBA'
#  'COLOMBIO' 'REPÚBLICA DOMINICANA' 'COLÒMBIA' 'FILIPINA' 'IRAN'
#  'MARRUECOS3' '-MARUECOS' '-PERU' 'RÚSSIA' 'PAISES BAJOS' 'MALI' 'MEXICO'
#  'INGLATERRA' 'EL SALVADOR' 'PAKISTANI' 'PORTUGAL' 'ARGENTINO' 'URIGUAY'
#  'ALEMAN' 'REGNE UNIT' '-GHANA' 'GHANA' 'PAQISTAN' 'MOLDAVIA' 'SALVADOR'
#  'ESTADOS UNIDOS' 'HOLLANDA' 'IRLANDA' 'ISTANBUL' 'XILE' 'URUGUAI'
#  'GUINE BISSAU' 'PUNJAB' 'TENERIFE' 'BRAZIL' 'BADAJOZ' 'SUECIA'
#  'FILIPINES' 'YUGOSLAVIA' 'AFGANISTAN' 'COSTA DE MARFIL' 'EQUADOR'
#  'SUÏSSA' 'TANGER' 'REPULICA DOMINICANA' 'SUIZA' 'TÚNEZ' 'AUSTRIA' 'EEUU'
#  'HONNDURAS' 'MEJICO' 'MARROQUÍ' 'BRASIL' 'MENDOZA-ARGENTINA' 'CHINO'
#  '-PAKISTAN' 'PAQUISTAN' 'LONDRES' 'CADAKISTAN' 'GUINEA' 'CHEQUIA'
#  'ARAGENTINA' '-ARGENTINA' 'KOREA' '-REPUBLICA DOMINICANA' 'ECUARO'
#  'MÈXIC' 'COSTA RICA' 'REP. DOMINICANA' 'BOLÍVIA' 'ITALIANO' 'HUESCA'
#  'JAPAN' 'GANA, ARICA' 'MARARUECOS' 'PERUANO' 'NAVARRA' 'TURQUIA'
#  'BRAZATORTAS' 'UCRAÏNA' 'GRAN BRETANYA' 'HOLANDES' 'MARROQUI' 'MARUECOS'
#  'GANDIA' 'ESPANYA' 'EL MARROC' 'MARRUECO' 'ROMANIA' 'ANGLATERRA'
#  'GUATEMALA' '-FRANÇA' 'PORTUGUES' 'MARRUECOD' 'PUERTO RICO' 'DOMINICANA'
#  'MACHAKOS-KENIA' 'HOLANDA' 'MARROQUI.' 'VALENCIA' 'GUINEA VISAO'
#  'ARGELINO' 'NIGERIAN' 'BULGÀRIA' 'AMRITSAR' 'RUMA' 'EGIPTO' 'RUMANÍA'
#  'JAPON' 'GALICIA' 'FRANCES' 'SANTO DOMINGO' '-MAROC' 'BÉLGICA' 'POLÒNIA'
#  'BOSTON, EEUU' '-MARRUECOS' 'BUENOS AIRES (ARGENTINA)']
#
#
# Valores únicos para la columna OR6#value:
# ['0' 'FILIPINAS' 'VENEZUELA' 'PERU' 'PARAGUAY' 'ECUADOR' 'PERÚ'
#  'ARGENTINA' 'MARROUECOS' 'CIUDAD MEJICO' 'UCRANIA' 'MARRUECOS' 'SUISSA'
#  'NUEVA YORK' 'COLOMBIA' 'GEORGIA' 'MARROC' 'INGLATERRA' 'PAKISTÁN'
#  'ITALIA' 'GAMBIA' 'URUGUAY' 'JAPÓ' 'CHINA' 'BOLIVIA' 'MARROQUI'
#  'REPÚBLICA DOMINICANA' 'RUMANIA' 'XINA' 'NADOR' 'NIGERIA' 'HONDURAS'
#  'FRANCIA' 'SENEGAL' 'JAPO' '-BRASIL' 'BANGLADESH' 'PAKISTAN' 'RUSIA'
#  'EGIPTE' 'PERSIA' 'NICARAGUA' 'LIBANO' '-ECUADOR+' 'ARGELIA' 'FRANÇA'
#  '-ECUADOR' '-PERU' 'ESPAÑA' 'MAROC' 'INDIA' 'ARMENIA'
#  'REPUBLICA DOMINICANA' 'BULGARIA' 'CUBA' 'COLÒMBIA' 'FILIPINA' 'PARGUAY'
#  '-IRAN' 'RÚSSIA' 'ALEMANYA' 'VENEZOLANA' 'PAISES BAJOS' 'MALI' 'MEXICO'
#  'EL SALVADOR' 'ESTATS UNITS' 'PORTUGAL' '-COLOMBIA' 'BÉLGICA' 'ALEMANIA'
#  'GHANA.' 'GHANA' 'PAQUISTAN' 'MOLDAVIA' 'SALVADOR' 'ALEMNAYA' 'HOLLANDA'
#  'IRLANDA' 'FRANCA' 'XILE' 'VENEZULEA' 'URUGUAI' 'GRECIA' 'SIRIA' 'PUNJAB'
#  'BRASIL' 'EQUADOR' '-MARROC' 'FILIPINES' 'AFGANISTAN' 'PAÏSOS BAIXOS'
#  'ESTADOS UNIDOS' '-ARGENTINA' 'MOSCU' 'TANGER' 'REPULICA DOMINICANA'
#  'SUÏSSA' 'TETUAN, MARROC (EN AQUELL MOMENT ERA ESPANYA)' '-HONDURAS'
#  'HONMDURAS' 'PERUANA' 'VENEÇUELA' 'KAZAHSTAN' '-FRANCIA' 'MEJICO'
#  'COREA DEL SUR' 'CHINO' 'RUMANÍA' '-EL SALVADOR' 'CHILE' 'LONDRES'
#  'CADAKISTAN' 'GUINEA' 'CHEQUIA' 'KIRGUISTÁN' 'KOREA' 'ITÀLIA' 'MÈXIC'
#  'COSTA RICA' 'SUIZA' 'REP. DOMINICANA' 'MAURITIUS' 'ARGENTINA.' 'UCRAINA'
#  'BÈLGICA' 'GANA, AFRICA' 'AUSTRIA' 'VENEZUELQ' 'SUECIA' 'NAVARRA' 'TUNEZ'
#  'CÓRDOBA' 'UCRAÏNA' 'JAÉN' 'SANTIAGO DE CHILE' 'GANDIA' 'EL MARROC'
#  'MARUUECOS' 'ROMANIA' 'GUATEMALA' 'FRANCES' 'MARRUECOD' 'ARAB'
#  'GUINEA EQUATORIAL' 'AUSTRALIA' 'MARUECOS' 'DOMINICANA' 'MACHAKOS -KENIA'
#  'GUINERA' 'NIGERIAN' '-MARRUECOS' 'BULGÀRIA' 'AMRITSAR' 'EGIPTO'
#  'POLONIA' 'GALICIA' 'HUELVA' 'REINO UNIDO' 'HOLANDA' 'SANTO DOMINGO'
#  'POLÒNIA' 'MARRUECOSW' 'ARG' 'EEUU']
#
#
# Valores únicos para la columna CS3#value:
# ['0' 'CURE' 'INGENIERIA Y CIENCIA' 'ARBITRE DE FUTBOL'
#  'OPERARIO DE PRODUCCION' 'CAJERO' 'LIMPIEZA' 'MOZO DE ALMACEN'
#  'CONSULTOR' 'DISEÑADOR' 'MAESTRO CHOCOLATERO' 'TELEOPERADOR'
#  'TECNICO INFORMATICO' 'INFORMATICO' 'MANTENIMIENTO' 'OPERARIO TANATORIO'
#  'ENGINYER AGRONOM' 'AUCILIAR ATRECISTA'
#  'TECNICO EN EMERGENCIAS SANITARIAS' 'TECNICO DE AMBULANCIA' 'SOMELIER'
#  'INTEGRADOR SOCIAL' 'MAQUINISTA A RODALIES DE CATALUNYA' 'ADMINISTRATIVO'
#  'SANITARIO' '-MOZO ALMACÉN' 'PERFIL JUNIOR'
#  'INGENIER DE PRACTIQUES EN LA SEAT' 'SEGURETAT PRIVADA' 'ANALISTA DATOS'
#  'TECNICO AUXILIAR EDUCATIVO' 'BOMBER' 'PROGRAMADOR'
#  '-TREBALLA AMB GENT QUE TE DISCAPCITAT' 'POLICIA' 'ADMINISTRACIO PUBLICA'
#  'BARTENDER' 'MECÀNIC' 'ENGINYER' 'CONTABLE' 'AYUDANTE DE ARTES GRAFICAS'
#  'EDUCADOR SOCIAL I MESTRE' 'MANTENIMIENTO DE CLIMA (AIRE ACONDICIONADO)'
#  'MECÁNICO DE VEHÍCULOS DE TURISMO' 'EDITOR ADIOVISUAL' 'MOZO DE ALMACÉN'
#  'MECÁNICO' 'PERFIL OPERARI' 'COCINERO' 'ADMINISTRATIU EN AMBULATORI'
#  'PALETA' 'TECNICO ESPECIALISTA' 'ADMINSITR' 'CAMARERO DE APARTAMENTOS'
#  'VENTES' 'TRANSPORTISTA' 'PINTOR' 'COLORISTA' 'INFORMATIC'
#  'EDUCADOR SOCIAL' 'CAP DE SALA POR CONCIERTOS' 'INDUSTRIA FARMACEUTICA'
#  'ALBAÑIL' 'ADVOCAT' 'HOSTELERIA' 'FUNCIONARI' 'INFERMER'
#  'CÀRREG INTERMIG AMB PERSONAL A CÀRREC' 'PAGES' 'CONSULTOR BI'
#  'ENGINYER DE SO'
#  'TÉCNICO EN MONTAJE Y MANTENIMIENTO DE PUERTAS EN ÁMBITO FERROVIARIO'
#  'TÈCNIC DE SOFTWARE' 'ACTOR' 'MESTRE XOCOLATER' 'GRADUADO SOCIAL'
#  'CONDUCTOR DE TRAILER' 'DOCENT' 'DISEÑADOR DE INTERIORES'
#  'OPERARIO TRABAJOS AGRICOLAS' 'ABOGADO'
#  'INGENIERO INDUSTRIAL (ELECTRONICA)' 'DE SEGURETAT INFORMATICA'
#  'INGENIERIO DE CALIDAD PROECTOS' 'PSICOLOGO'
#  'TREBALLADOR DE SEGURETAT EN UNA DEIXALLERIA MUNICIPAL' 'MEDICO'
#  '-ADMINISTRADOR DE SISTEMAS Y REDES' 'DISEÑADOR AUDIOVISUAL'
#  'CARRETILLERO' 'INFORMAT5ICO' 'ENCARGADO DE ENVASADO'
#  'ADMINISTRADOR FINCAS' 'EMPRESA DE SERVICIOS AUDIVISUALES CON DRONES'
#  'RECARGO AQUINAS VENDING' 'PROFESOR E SECUNDARIA' 'RESTAURANTE'
#  'EN LA OBRA' 'OPERARIO CUALIFICADO SECTOR METAL' 'QUIMICO'
#  'TECNICO TELECOMUNICACIONES' 'FINANCER' 'MAGATZEM' 'TÉCNICO'
#  'ADMINSTRATIVU' 'REPONEDOR' '-TÉCNICO AUTOMONOCION' 'VIGILANTE'
#  'AYUDANTE' 'SERVICIOS FUNERARIOS' 'EMPLEADO DE CORREOS' 'PROFESOR'
#  'DISSENYADOR' 'TRANSPORT' 'MECANICO INDUSTRIAL' 'OBRA' 'COMERCIAL'
#  'ENGINYERIA Y PROJECTES' 'MECANICO' 'ENTRENADOR DEPORTIVO'
#  'FORMADOR VIARI' 'CONDUCTOR AUTOBUS' 'PLANCHISTA AUTOMOCIÓN'
#  'ATENCIO AL CLIENT' '-FINANCIERO' 'SOLDADOR' 'REPARTIDOR'
#  'ESTILISTA DE MODA' 'PROFESSOR DE SECUNDÀRIA'
#  '-COMERCIALDE SERVICIOS DEJ TRANSPORTE INTERNACIONAL'
#  'DELINEANT PROJECTISTA' 'CONDUCTOR'
#  'JEFE  DE4 PRODUCCION ELECTRONICA Y EGIPTOLOGO' 'VENDEDOR'
#  'TÈCNIC DE PROJECTES' 'REPARACIONES DE MAQUINARIA HOSTELERIA'
#  'TECNICO MANTENIMIENTO' 'PUBLICITAT MERCHANDISING' 'DRET'
#  'MECANICA INDUSTRIAL' 'MAESTRO DE PRIMARIA' 'CONSERGE' 'CAMIONERO'
#  'INSPECTOR EDUCACIÓ' 'COMERCIAL, VENEDOR' 'ÀREA COMERCIAL EN TECNOLOGÍA'
#  "CAP DE VENDES D'UNA EMPRESA DE MUDANCES" 'GUARDIA URBANO' 'ESPECIALISTA'
#  'NIÑERA' 'CONDIS' 'GABINETE' 'TREBALLADORA DEL SECTOR DEL TURISME'
#  'PROFESORA DE BAILE' 'EDUCACIÓ, MONITORATGE DE TEMPS LLIURE'
#  'CAMARERA DE HABITACION' 'EDUCADORA INFANTIL' 'SANIDAD'
#  "AUXILIAR D'INFERMERIA" 'DEPENDIENTA' 'HIGIENISTA DENTAL'
#  'AGENTE DE RESERVAS' 'AGENTE ATENCION CLIENTE'
#  'BECARI DEPARTAMENT DE FORMACIÓ' 'PROFESORA DE PRIMARIA PER LA PÚBLICA'
#  'DEP' 'TECNICA AUDIOVISUAL' 'ESTETICISTA' 'MONITORA DE MENJADOR'
#  'AUXILIAR DE ENFERMERIA' 'AGENTE DE VIAJES' 'OFICINA INDUSTRIAL'
#  'ESTETICIENT' 'ARTS ESCÈNIQUES' 'MESTRA D?INFANTIL' 'METGE'
#  'MAQUILLADORA' 'FARMACIA' 'ESTILISTA' 'AUXILIAR DE ENFERMERÍA'
#  'TECNIC MEDIAMBIENTAL' 'AGENTE OPERATIVA' 'COMUNICACIO I MARQUETING.'
#  'DEPENDETA CARNICERIA' 'CUIDADORA DE PERSONAS MAYORES'
#  'DISSENYADORA, PROJECT MANAJER I PRODUCT DEVELOPER' 'PROFESORA DE NGLES'
#  'ADMINSITRATIVA' 'LIMPI' 'MAESTRA DE PRIMARIA'
#  'PORTA UNA TENDA ON-LINE (ATENCIO CLIENT O MARKETING)'
#  "MESTRA D'EDUCACIO INFANTIL J PRIMARIA" 'MESTRA PRIMÀRIA'
#  'AUX. ADMINISTRATIVO' 'MONITOR MIG DIA' 'CAMRERA' 'PROFESORA'
#  'FUNCIONARIA DEL ESTADO' 'DIRECTORA DE LLEURE' 'RETAI' 'INFERMERA'
#  'MOZO ALMACÉN' 'INGENIERA' 'TELEOPERADORA' 'TRABAJADOR LOGÍSTICA'
#  'CAJERA DE SUPER' 'PROFESSORA' 'ABOGADA' 'CUIDADAORA'
#  'TREBALLADORA SOCIAL' 'RECURSOS HUMANOS' 'FUNDACION DE EDUCADORA'
#  'TRABAJA CON ABUELA' "PROFESSORA D'ANGLÈS A ESCOLA OFICIAL D'IDIOMES"
#  'EDUCADORA' 'CAMERERA DE RESTAURACION' 'MESTRA' 'SECRETARIA ACADEMICA'
#  'CUIDADORA' 'DOCENTE' 'SPICOLOGA'
#  'FINANCES, DEPARTAMENT FINANCES, TECNICA' 'OFICINISTA'
#  'VISUAL MERCHANDISING' 'INVESTIGADORA PREDOCTORAL I DONA TAMBÉ CLASSES'
#  'TÉCNICO LÁSER' '-MARQUETING ONLINE (TRAFIC MANAGER)'
#  'INDUSTRIA DE LOS EVENTOS DE MUSICA' 'CUIDADO ADULTO MAYOR' 'QUÍMICA'
#  'EDUCACIÓ' 'DEPENDIENTE' 'PERIDODISTA' 'MANAGER' 'TREBALLADORA FAMILIAR'
#  'COMUNICACIÓ' 'AYUDA A DOMICILIO' 'EDUCACIÓN' 'ADVOCATAD' 'EXPENDEDOR'
#  'ADMINISTRATIVA' 'CUIDADORA MAYORES' 'REPONEDORA' 'JARDINERA'
#  '-OPERARIA DE LABORATORIO DE UNA FABRICA FARMACEUTICA MULTINACIONAL'
#  'OPERARIA DE FÁBRICA' 'CAMARERA DE PISOS DE HOTEL' 'PROFESORA INSTITUT'
#  'SUPERMERCADO' 'FUNCIONARIA DE CARRERA' 'LOGISTICA'
#  'AUXILIAR D?INFERMERIA' 'CUIDADO DE PERSONAS MAYORES'
#  "ADMINISTRATIVA A L' ADMINISTRACIÓ LOCAL" 'MOZO REPONEDOR'
#  'TÉCNICO COMERCIAL.' 'TEXTIL' 'PROFESORA DE CICLES FORMATIUS'
#  'EMPRESA CATERING' 'PROFESSORAT FP' 'RESPONSABLE DE PLANTA , METALURGIA'
#  '-MANIPULADORA DE ARTES GRAFICAS' 'PRODUCCIÓ AUDIOVISUALS'
#  'AX ADMINISTRATIVA' 'SECRTEARIA AYUNTAMIENTY' 'MARKETING I DISSENY'
#  'ARQUITECTA' 'CONTROLLER' "EDUCADORA D'EDUCACIO ESPECIAL" 'DOMÉSTICA'
#  'AJUDA A LA DEPENDENCIA' 'FISIOTERAPEUTA' 'ASSEGURANCES' 'BARRENDERA'
#  'FUNCIONARIA' 'RECUROS HUANOS' 'PEDAGOGA'
#  "ENCARREGADA DE LA NETEJA D'UNA ESCOLA" 'CONSERJE'
#  'ENCUESTADORA TELEFONICA ESTUDIOS DE MERCADO' 'AUSILIAR ENFERMERIA'
#  'LIMPIADORA' 'ALMACEN' 'MAQUILLA Y SALUD' 'INFERMERIA'
#  'AUILIAR ADMINSITRATIAVA' 'OPERARIO' 'CAMARERO' 'RAMADER I PAGES'
#  'MECÁNICA' 'ENCARREGAT DE OBRES' 'ENGINYER QUIMIC' 'ENTRENADOR DE SALUT'
#  'TRABAJA EN UNA LAVANDERIA' 'AUDIOVISUALS' 'PROFESOR DE SECUNDARIA'
#  'RECEPCIONISTA DE UN HOTEL' 'RECURSOS HUMANS'
#  'TECNICO DE REPARACION DE DECORACIONES' 'SERVIDOR PUBLIC'
#  'DIRECCION DE OBRAS DE FIBRA OPTICA' 'PALETA Y JARDINERO' 'CARNICA'
#  'CARPINTERIA' "COMERCIAL DE PRODUCTES D'HOSTELERIA ALIMENTARIA"
#  'PROFESSOR SECUNDÀRIA' 'SUMILLER' 'ÀMBIT DE SERVEIS SOCIALS'
#  'DIVERSOS   LO QUE LE TOCA' 'TÉCNICO EN TELECOMUNICACIONES'
#  'VENDEDOR DE MARROQUINERIA' 'EMPRESA DE CONSTRUCCIONES METALICAS'
#  'GASOLINERA' 'DEPORTISTA EQUINA Y DOMADORA Y ENTRENADORA DE CABALLOS'
#  'CAJERA' 'TÈCNIC ATENCIÓ SOCIOSANITÀRIA' 'PERIODISTA'
#  'ATENCIO AL CLIENT DEPARTAMENTS ATENCIO MARITIMA'
#  'TÉCNICA DE LABORATORIO' 'CAIXERA I REPOSAR EN SUPERMERCAT'
#  'OPERARIA DE FABRICA' 'DISEÑO' 'PERRUQUERA' 'CAMAREA'
#  'DEPENDENTA EN BOTIGA DEL MUSEU  DALÍ' 'SANITARIA' 'PARQUE TEMÁTICO'
#  'AYUDANTE COCINA' 'INGENIER' 'ELECTRICISTA' 'MEDICO FORENSE' 'MESTRE'
#  "FUNCIONARI. TÈCNIC D'HISENDA." 'INTERMEDIARI IMMOBILIARI'
#  'DEPARTAMENT DE COMPRES EMPRESA DE RECICLATGE'
#  'PERFIL OPERARIO (MAQUINISTA)' 'PEON DE OBRA' 'PERFIL OPERARIO'
#  'GUÍA TURÍSTIC' 'SERVICIOS DE LIMPIEZA DE SALOU' '-MAQUINISTA'
#  'AUTOMOCIO' 'MOZO DE ALMAZEN' 'CANTERA' "AUXILIARS D'INFERMERIA"
#  'MONITORA MENJADOR' 'PELUQUERÍA I ESTÉTICA'
#  "TÈCNIC AUXILIAR D'INFERMERIA" 'TIENDA' 'EDUCACIÓ INFANTIL' 'ADVOCADA'
#  'COCINERA' 'GUIA I EDUCADORA' 'OPERARIA DE FABRICA INDUSTRIA'
#  'MONITORA, RECEPCIONISTA' 'ENFERMERA' 'CAMARERA DE PISOS'
#  'CÀRREG INTERMIG AMB PERSONAL AL SEU CÀRREC' 'TECNIC DE LABORATORI'
#  'DEPENDIENTA TIENDA ALIMENTACIÓN' 'ENCARREGAT AGRÍCOLA' 'JARDINERO'
#  'INVESTIGADOR DE UNIVERSITAT INGENIERIA TECNICA'
#  'ENCARREGAT DE MAGATZEM (AMB PERSONES AL SEU CÀRREC).'
#  'CUIDADO DE PERSONA MAYOR' 'AUX DE FARMACIA' 'OPERADOR DE PRODUCCION'
#  'TÈCNIC AUDIOVISUAL EN ESDEVNIMENTS EN DIRECTE (CONCERTS, TEATRE, FESTIVALS, ETC.)'
#  'FORESTALES' 'CONTRAMAESTRE EN UNA LINEA DE FABRICA' 'CARPENTIRO'
#  'LOGISTIC (SECTOR METALURGIC)' 'CONSIGNATARI DE CREUERS' 'FUSTER'
#  'SECTOR ALIMENTARI' 'MECANIC' 'MINERO' 'INGENIER QUIMIC'
#  'PEO DE BRIGADA DE AJUNATAMENT' 'QUIMICO, OPERADOR DE PLANTA'
#  'PERRUQUERIA CANINA' "PROFESSORA D'ANGLÈS D'ACADEMIA" 'LOGOPEDA'
#  'PSICOMOTRICISTA' 'AUIXILIAR CLINICA' 'OFICIAL DE 1ª'
#  'DOCENT DE SECUNDÀRIA' 'DESARROLLADOR DE APLICACIONES'
#  'TECNIC DE LOGISTICA EN EMPRESA DE TRANSPORTS' 'PEON AGRICOLA'
#  'PERFIL TÉCNICO' 'CHOFER PROTA UN CAMIO'
#  'RELACIONS LABORALS I RECURSOS HUMANS' 'TECNIC ADMINOISTRACIO'
#  'CAP DE TALLER DE MANTENIMENT - CÀRREC INTERMIG AMB PERSONAL AL SEU CÀRREG.'
#  'ELCTROMECANIC' 'AUTOMÓVIL' 'GRANJERO' 'ENCARREGAT DE LOGISTICA'
#  'DEPARTAMENT DE MÀRQUETING' 'ATENCION AL CLIENTE' 'CUIDADORA - LIMPIEZA'
#  'PROFESSORA I ENTRENADORA' 'CAMARERA' 'COMERCIAL EXPORTACIO'
#  'OPERARIA  DE CAMPAÑA AGRICOLA' 'MOZO FARMACIA' 'VENDEDORA DE CUPONS'
#  'PILOT' 'PILOT DE LÍNIA AÈREA' 'FUNCIONARIA PÚBLIC (ADMINISTRATIU)'
#  'MANCOMUNIDAT' 'DOCÈNCIA' "MESTRA D'EDUCACIÓ PRIMÀRIA" 'MAESTRA'
#  "MONITOR D'ESCOLA" 'OBRAS Y CONSTRUCCIÓN' 'PAISAGISTA'
#  'CAP DE SALA DE UN TEATRE'
#  "EMPRESA D' INSERCIO LABORAL JARDINER I CUIDADOR DE AQUESTES PERSONES AMB DIFICULTAT"
#  'FUNCIONARIO' 'SOCIOSANITARIO' 'PROFESOR ATTUOESCUELA' 'ARTS GRAFIQUES'
#  'METALURGICA' 'EMPAQUETADORA DE MEDICAMENTOS' 'PANADERA'
#  'ADMINISTRATIVA FINANCIERA' 'MESTRA EDUCACIÓ ESPECIAL' 'VENDEDORA'
#  'ASESORA DE SERVICIOS EN TALLER'
#  'ARQUEÒLOGA, ANTROPOLOGA FISICA I HISTÒRIADORA' 'ENSENYAMENT'
#  'OPERARIA FÀBRICA' 'REPARTO CORRESPONDENCIA Y PAQUETERIA'
#  'ADMINISTRATIVA ADMINISTRACIO PUBLICA' 'SUPERVISORA'
#  'MONITORA DE COMEDOR']
